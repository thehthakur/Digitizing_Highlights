# %%
import cv2
import numpy as np
import random
import torch
from PIL import Image
import json
import os

random.seed(42)

# %%
def image_preprocess(image_path, resized_height=1600, resized_width=1200):
    #resize img
    image = cv2.imread(image_path)
    overlay_image = cv2.resize(image, (resized_width, resized_height))

    # black background overlay
    resized_dimension = resized_height
    black_background = np.zeros((resized_dimension, resized_dimension, 3), dtype=np.uint8)
    overlay_height, overlay_width = overlay_image.shape[:2]
    black_background[0:overlay_height, 0:overlay_width] = overlay_image

    return black_background

# %%
def add_random_offset(point, max_offset):
        return point + random.randint(-max_offset, max_offset)

# %%
def random_rgb_color():
    r = random.randint(0, 175)
    g = random.randint(0, 175)
    b = random.randint(0, 175)
    return (r, g, b)

# %%
def draw_broken_box_with_subboxes(background, rect_start, width, height_in_lines, thickness, delta, l1, l2, max_offset=10, color=(0, 255, 0), opacity=0.5):
    """
    Draw a rectangular box broken into smaller subboxes with slight irregularities in width and height.
    
    Parameters:
        background (OpenCV Image): OpenCV Matrix representing the (already resized) image.
        rect_start (tuple): Starting coordinate (x, y) of the rectangle (top-left corner).
        width (int): Width of the overall rectangle.
        height (int): Height of the overall rectangle.
        thickness (int): Height of each smaller subbox.
        delta (int): Reduction in height for each smaller subbox.
        max_offset (int): Maximum random offset for width irregularity (in pixels).
        color (tuple): Color of the rectangle (BGR format).
        opacity (float): Opacity of the shape (0: fully transparent, 1: fully opaque).
        
    Returns:
        result_img (ndarray): Image with the broken box and irregular subboxes.
        bbox (dict): Metadata of the bounding box for YOLO.
    """
    # height in pixels
    height_in_pixels = height_in_lines*thickness
    
    # Create an overlay image (same size as the background)
    overlay = background.copy()

    # Define the top-left starting point of the rectangle
    x, y = rect_start
    
    # Number of subboxes along the height
    num_subboxes = height_in_lines
    print(f"num_subboxes = {num_subboxes}")
    img_height, img_width, _ = overlay.shape
    print(f"img_width = {img_width}, img_height = {img_height}")
    # Initialize the bounding box metadata
    # every object in the labels file has the following line: <class-index> <x1> <y1> <x2> <y2> ... <xn> <yn>.
    # it is not necessary that each object segment has the same number of x,y points
    # However, there should be minimum of 3 x,y points for each object
    # in our case, the segmenting polygon of a highlight will be defined using 8 coordinates
    
    bbox = {
        "class": 0,                                            # Assuming class 0 for YOLO
        "poly": [
            [(x+l1)/img_width, (y+thickness)/img_height],
            [(x+l1)/img_width, y/img_height],
            [(x+width)/img_width, y/img_height],
            [(x+width)/img_width, (y+height_in_pixels-thickness)/img_height],
            [(x+width-l2)/img_width, (y+height_in_pixels-thickness)/img_height],
            [(x+width-l2)/img_width, (y+height_in_pixels)/img_height],
            [x/img_width, (y+height_in_pixels)/img_height],
            [x/img_width, (y+thickness)/img_height]
        ]
        #"x_center": (x + width / 2) / background.shape[1],  # Normalize x center
        #"y_center": (y + height_in_pixels / 2) / background.shape[0],  # Normalize y center
        #"width": width / background.shape[1],                # Normalize width
        #"height": height_in_pixels / background.shape[0],              # Normalize height
    }
    

    # Iterate over each subbox to create the broken box pattern
    for i in range(num_subboxes):
        # Starting Y position of the current subbox
        subbox_start_y = y + i * thickness
        # Ending Y position of the current subbox (apply delta to reduce height)
        subbox_end_y = subbox_start_y + thickness - delta
            
        # Apply random width variation
        random_width_start = add_random_offset(x, max_offset)
        random_width_end = add_random_offset(x + width, max_offset)

        # Using half of random width offset as the random height offset
        random_height_offset = max_offset//2

        if(i == 0):
            random_width_start += l1
        elif(i == num_subboxes-1):
            random_width_end -= l2
        
        # Define the points of the subbox (irregular rectangle)
        pts = np.array([
            [add_random_offset(random_width_start, max_offset), add_random_offset(subbox_start_y, random_height_offset)],  # Top-left
            [add_random_offset(random_width_end, max_offset), add_random_offset(subbox_start_y, random_height_offset)],    # Top-right
            [add_random_offset(random_width_end, max_offset), add_random_offset(subbox_end_y, random_height_offset)],      # Bottom-right
            [add_random_offset(random_width_start, max_offset), add_random_offset(subbox_end_y, random_height_offset)]     # Bottom-left
        ], np.int32)
        
        # Draw the subbox on the overlay
        cv2.fillPoly(overlay, [pts], color)
    
    # Perform alpha blending (opacity) between the background and overlay
    result_img = cv2.addWeighted(overlay, opacity, background, 1 - opacity, 0)

    return result_img, bbox

# %%
training_custom_metadata = './background_images/train/metadata_train.json'

with open(training_custom_metadata, 'r') as f:
    metadata = json.load(f)

# %%
import math
training_dataset_path = "./background_images/train"
training_bbox_data = './generated_dataset/labels/train/'
generated_train_dataset_path = "./generated_dataset/images/train/"
resized_img_height = 1600
resized_img_width = 1200
variations_per_image = 5

for image in metadata["images"]:
    image_filename = image["filename"]
    image_path = os.path.join(training_dataset_path, image_filename)
    # bg_img = image_preprocess(image_path, 1600)
    bg_img = cv2.imread(image_path)
    intermediate_img = bg_img

    # Save each variation with a unique filename
    filename, extension = os.path.splitext(image_filename)
    
    for var in range(variations_per_image):
        intermediate_img = bg_img

        # create a path string representing a fresh file for this image variation
        result_image_name = f"{filename}_variation{var}{extension}"
        result_metadata_name = f"{filename}_variation{var}.txt"
        training_bbox_data_file = f"{training_bbox_data}{result_metadata_name}"

        # flush previous contents if present
        with open(training_bbox_data_file,"w") as f:
            f.write("")
        
        with open(training_bbox_data_file, "a") as f:
            for box_num, box in enumerate(image["boxes"]):
                # 10% chance there is no highlight in this paragraph/box
                is_not_highlighted = random.randint(0, 9)
                if(is_not_highlighted<1):
                    continue
                
                # Get initial box parameters
                original_rect_start = box["rect_start"][:]
                width = box["width"]
                height = box["height"]
                thickness = box["thickness"]
                delta = box["line_spacing"]
                
                start_line = 0 # absolute line number from where highlight begins 
                max_lines = round(height // thickness, 0)
                lines_left_in_box = max_lines
                
                while lines_left_in_box>0:  
                    # 20% chance there is no highlight in the rest of the box
                    is_not_highlighted = random.randint(1, 10)
                    if(is_not_highlighted < 3):
                        lines_left_in_box = 0
                        continue
                        
                    # else, set random starting position within the remaining rectangle bounds
                    if(start_line == max_lines-1):
                        random_line_for_highlight_start = start_line
                    else:
                        random_line_for_highlight_start = random.randint(start_line, max_lines-1) # measured in number of lines, not pixels.
                    
                    lines_left_in_box = max_lines - random_line_for_highlight_start
                    variation_rect_start = original_rect_start[:]
                    variation_rect_start[1] += thickness*random_line_for_highlight_start
                    highlight_height =  random.randint(1, lines_left_in_box) # height of highlight-box in number of lines
                    
                    # new values for start_line and lines_left_in_box
                    start_line = random_line_for_highlight_start + highlight_height
                    lines_left_in_box = max_lines - start_line
    
                    # Ensure the rectangle is within the image bounds
                    #variation_rect_start[1] = min(variation_rect_start[1], resized_img_height - adjusted_height)
                    
                    l1, l2 = random.randint(0, 100), random.randint(0, 100)
                    max_offset = random.randint(0, 10)
                    color = random_rgb_color()
                    opacity = random.uniform(0.2, 0.6)
    
                    print(f"box = {box_num} \n rect_start = {variation_rect_start}\n width = {width} \n height = {highlight_height} \n opacity= {opacity}")
                    # Draw the adjusted rectangle
                    intermediate_img, bbox_metadata = draw_broken_box_with_subboxes(
                        intermediate_img, variation_rect_start, width, highlight_height, thickness, delta, l1, l2, max_offset, color, opacity
                    )

                    # create line to be appended to the image label file
                    line_to_be_appended = f"{bbox_metadata['class']}"
                    spaces=0
                    print(bbox_metadata)
                    for coord in bbox_metadata["poly"]:
                        line_to_be_appended = line_to_be_appended + f"{coord[0]} {coord[1]}"
                        if(spaces<8):
                            line_to_be_appended = line_to_be_appended + " "
                        spaces += 1
                    # append that line to the image path
                    f.write(f"{line_to_be_appended}\n")
                    
            result_image_filepath = os.path.join(generated_train_dataset_path, result_image_name)
            print(f"\n")
                
            cv2.imwrite(result_image_filepath, intermediate_img)
            #json.dump(bbox_metadata, f)  # Append the JSON object (box) to the file
            f.write("\n")  # Write each box on a new line
# Out:
# box = 0
#  rect_start = [218, 218]
#  width = 646
#  height = 1
#  opacity= 0.3334899160812824
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.205, 0.15375], [0.205, 0.13625], [0.72, 0.13625], [0.72, 0.13625], [0.7091666666666666, 0.13625], [0.7091666666666666, 0.15375], [0.18166666666666667, 0.15375], [0.18166666666666667, 0.15375]]}
# box = 0
#  rect_start = [218, 246]
#  width = 646
#  height = 1
#  opacity= 0.3393542733055418
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1975, 0.17125], [0.1975, 0.15375], [0.72, 0.15375], [0.72, 0.15375], [0.6491666666666667, 0.15375], [0.6491666666666667, 0.17125], [0.18166666666666667, 0.17125], [0.18166666666666667, 0.17125]]}
# box = 1
#  rect_start = [215, 395]
#  width = 656
#  height = 7
#  opacity= 0.3709812639939347
# num_subboxes = 7
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.22666666666666666, 0.261875], [0.22666666666666666, 0.246875], [0.7258333333333333, 0.246875], [0.7258333333333333, 0.336875], [0.6491666666666667, 0.336875], [0.6491666666666667, 0.351875], [0.17916666666666667, 0.351875], [0.17916666666666667, 0.261875]]}
# box = 1
#  rect_start = [215, 635]
#  width = 656
#  height = 2
#  opacity= 0.49879814427435787
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.2375, 0.411875], [0.2375, 0.396875], [0.7258333333333333, 0.396875], [0.7258333333333333, 0.411875], [0.6816666666666666, 0.411875], [0.6816666666666666, 0.426875], [0.17916666666666667, 0.426875], [0.17916666666666667, 0.411875]]}
#
#
# box = 0
#  rect_start = [218, 218]
#  width = 646
#  height = 1
#  opacity= 0.506167081542088
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.2075, 0.15375], [0.2075, 0.13625], [0.72, 0.13625], [0.72, 0.13625], [0.7125, 0.13625], [0.7125, 0.15375], [0.18166666666666667, 0.15375], [0.18166666666666667, 0.15375]]}
# box = 0
#  rect_start = [218, 246]
#  width = 646
#  height = 1
#  opacity= 0.20434703050968253
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.25, 0.17125], [0.25, 0.15375], [0.72, 0.15375], [0.72, 0.15375], [0.7166666666666667, 0.15375], [0.7166666666666667, 0.17125], [0.18166666666666667, 0.17125], [0.18166666666666667, 0.17125]]}
#
#
# box = 0
#  rect_start = [218, 218]
#  width = 646
#  height = 1
#  opacity= 0.5290019862234465
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.22416666666666665, 0.15375], [0.22416666666666665, 0.13625], [0.72, 0.13625], [0.72, 0.13625], [0.6541666666666667, 0.13625], [0.6541666666666667, 0.15375], [0.18166666666666667, 0.15375], [0.18166666666666667, 0.15375]]}
# box = 0
#  rect_start = [218, 246]
#  width = 646
#  height = 1
#  opacity= 0.21121954393246745
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1925, 0.17125], [0.1925, 0.15375], [0.72, 0.15375], [0.72, 0.15375], [0.7091666666666666, 0.15375], [0.7091666666666666, 0.17125], [0.18166666666666667, 0.17125], [0.18166666666666667, 0.17125]]}
# box = 1
#  rect_start = [215, 323]
#  width = 656
#  height = 8
#  opacity= 0.5945975893444588
# num_subboxes = 8
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.2075, 0.216875], [0.2075, 0.201875], [0.7258333333333333, 0.201875], [0.7258333333333333, 0.306875], [0.7175, 0.306875], [0.7175, 0.321875], [0.17916666666666667, 0.321875], [0.17916666666666667, 0.216875]]}
# box = 1
#  rect_start = [215, 683]
#  width = 656
#  height = 1
#  opacity= 0.3603756857187546
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.19166666666666668, 0.441875], [0.19166666666666668, 0.426875], [0.7258333333333333, 0.426875], [0.7258333333333333, 0.426875], [0.6658333333333334, 0.426875], [0.6658333333333334, 0.441875], [0.17916666666666667, 0.441875], [0.17916666666666667, 0.441875]]}
# box = 1
#  rect_start = [215, 707]
#  width = 656
#  height = 1
#  opacity= 0.5509634491072191
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1875, 0.456875], [0.1875, 0.441875], [0.7258333333333333, 0.441875], [0.7258333333333333, 0.441875], [0.6533333333333333, 0.441875], [0.6533333333333333, 0.456875], [0.17916666666666667, 0.456875], [0.17916666666666667, 0.456875]]}
#
#
#
#
# box = 0
#  rect_start = [218, 218]
#  width = 646
#  height = 2
#  opacity= 0.3395751847799945
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.18916666666666668, 0.15375], [0.18916666666666668, 0.13625], [0.72, 0.13625], [0.72, 0.15375], [0.6966666666666667, 0.15375], [0.6966666666666667, 0.17125], [0.18166666666666667, 0.17125], [0.18166666666666667, 0.15375]]}
# box = 1
#  rect_start = [215, 659]
#  width = 656
#  height = 1
#  opacity= 0.2582055200344812
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.20833333333333334, 0.426875], [0.20833333333333334, 0.411875], [0.7258333333333333, 0.411875], [0.7258333333333333, 0.411875], [0.6775, 0.411875], [0.6775, 0.426875], [0.17916666666666667, 0.426875], [0.17916666666666667, 0.426875]]}
# box = 1
#  rect_start = [215, 683]
#  width = 656
#  height = 2
#  opacity= 0.22770361981959733
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.2075, 0.441875], [0.2075, 0.426875], [0.7258333333333333, 0.426875], [0.7258333333333333, 0.441875], [0.6991666666666667, 0.441875], [0.6991666666666667, 0.456875], [0.17916666666666667, 0.456875], [0.17916666666666667, 0.441875]]}
#
#
# box = 0
#  rect_start = [112, 162]
#  width = 901
#  height = 2
#  opacity= 0.5132289495878795
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13083333333333333, 0.13875], [0.13083333333333333, 0.10125], [0.8441666666666666, 0.10125], [0.8441666666666666, 0.13875], [0.7708333333333334, 0.13875], [0.7708333333333334, 0.17625], [0.09333333333333334, 0.17625], [0.09333333333333334, 0.13875]]}
# box = 3
#  rect_start = [131, 1253]
#  width = 903
#  height = 2
#  opacity= 0.588697802065695
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1725, 0.820625], [0.1725, 0.783125], [0.8616666666666667, 0.783125], [0.8616666666666667, 0.820625], [0.8216666666666667, 0.820625], [0.8216666666666667, 0.858125], [0.10916666666666666, 0.858125], [0.10916666666666666, 0.820625]]}
# box = 3
#  rect_start = [131, 1433]
#  width = 903
#  height = 1
#  opacity= 0.43795672405557967
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1275, 0.933125], [0.1275, 0.895625], [0.8616666666666667, 0.895625], [0.8616666666666667, 0.895625], [0.8133333333333334, 0.895625], [0.8133333333333334, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.933125]]}
#
#
# box = 3
#  rect_start = [131, 953]
#  width = 903
#  height = 8
#  opacity= 0.37764134259033655
# num_subboxes = 8
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.18833333333333332, 0.633125], [0.18833333333333332, 0.595625], [0.8616666666666667, 0.595625], [0.8616666666666667, 0.858125], [0.7816666666666666, 0.858125], [0.7816666666666666, 0.895625], [0.10916666666666666, 0.895625], [0.10916666666666666, 0.633125]]}
# box = 3
#  rect_start = [131, 1433]
#  width = 903
#  height = 1
#  opacity= 0.41416688811915153
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.12833333333333333, 0.933125], [0.12833333333333333, 0.895625], [0.8616666666666667, 0.895625], [0.8616666666666667, 0.895625], [0.8366666666666667, 0.895625], [0.8366666666666667, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.933125]]}
#
#
# box = 1
#  rect_start = [113, 345]
#  width = 903
#  height = 1
#  opacity= 0.39769802047200087
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.10916666666666666, 0.253125], [0.10916666666666666, 0.215625], [0.8466666666666667, 0.215625], [0.8466666666666667, 0.215625], [0.8166666666666667, 0.215625], [0.8166666666666667, 0.253125], [0.09416666666666666, 0.253125], [0.09416666666666666, 0.253125]]}
# box = 1
#  rect_start = [113, 405]
#  width = 903
#  height = 1
#  opacity= 0.3195019930903324
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13416666666666666, 0.290625], [0.13416666666666666, 0.253125], [0.8466666666666667, 0.253125], [0.8466666666666667, 0.253125], [0.8133333333333334, 0.253125], [0.8133333333333334, 0.290625], [0.09416666666666666, 0.290625], [0.09416666666666666, 0.290625]]}
# box = 2
#  rect_start = [115, 524]
#  width = 903
#  height = 2
#  opacity= 0.21182209711061173
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.15083333333333335, 0.365], [0.15083333333333335, 0.3275], [0.8483333333333334, 0.3275], [0.8483333333333334, 0.365], [0.77, 0.365], [0.77, 0.4025], [0.09583333333333334, 0.4025], [0.09583333333333334, 0.365]]}
# box = 2
#  rect_start = [115, 764]
#  width = 903
#  height = 1
#  opacity= 0.5689392393620438
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.145, 0.515], [0.145, 0.4775], [0.8483333333333334, 0.4775], [0.8483333333333334, 0.4775], [0.7691666666666667, 0.4775], [0.7691666666666667, 0.515], [0.09583333333333334, 0.515], [0.09583333333333334, 0.515]]}
# box = 3
#  rect_start = [131, 1013]
#  width = 903
#  height = 4
#  opacity= 0.49883170804880234
# num_subboxes = 4
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.18583333333333332, 0.670625], [0.18583333333333332, 0.633125], [0.8616666666666667, 0.633125], [0.8616666666666667, 0.745625], [0.81, 0.745625], [0.81, 0.783125], [0.10916666666666666, 0.783125], [0.10916666666666666, 0.670625]]}
# box = 3
#  rect_start = [131, 1373]
#  width = 903
#  height = 1
#  opacity= 0.42698770104420014
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.11, 0.895625], [0.11, 0.858125], [0.8616666666666667, 0.858125], [0.8616666666666667, 0.858125], [0.8283333333333334, 0.858125], [0.8283333333333334, 0.895625], [0.10916666666666666, 0.895625], [0.10916666666666666, 0.895625]]}
# box = 3
#  rect_start = [131, 1433]
#  width = 903
#  height = 1
#  opacity= 0.27884930089014687
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.18166666666666667, 0.933125], [0.18166666666666667, 0.895625], [0.8616666666666667, 0.895625], [0.8616666666666667, 0.895625], [0.7816666666666666, 0.895625], [0.7816666666666666, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.933125]]}
#
#
# box = 0
#  rect_start = [112, 222]
#  width = 901
#  height = 1
#  opacity= 0.5951819062371462
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.15416666666666667, 0.17625], [0.15416666666666667, 0.13875], [0.8441666666666666, 0.13875], [0.8441666666666666, 0.13875], [0.8425, 0.13875], [0.8425, 0.17625], [0.09333333333333334, 0.17625], [0.09333333333333334, 0.17625]]}
# box = 1
#  rect_start = [113, 345]
#  width = 903
#  height = 2
#  opacity= 0.2319068835867947
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.17083333333333334, 0.253125], [0.17083333333333334, 0.215625], [0.8466666666666667, 0.215625], [0.8466666666666667, 0.253125], [0.815, 0.253125], [0.815, 0.290625], [0.09416666666666666, 0.290625], [0.09416666666666666, 0.253125]]}
# box = 3
#  rect_start = [131, 1373]
#  width = 903
#  height = 1
#  opacity= 0.5788579443224968
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1825, 0.895625], [0.1825, 0.858125], [0.8616666666666667, 0.858125], [0.8616666666666667, 0.858125], [0.8566666666666667, 0.858125], [0.8566666666666667, 0.895625], [0.10916666666666666, 0.895625], [0.10916666666666666, 0.895625]]}
# box = 3
#  rect_start = [131, 1433]
#  width = 903
#  height = 1
#  opacity= 0.46729410029164936
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.12416666666666666, 0.933125], [0.12416666666666666, 0.895625], [0.8616666666666667, 0.895625], [0.8616666666666667, 0.895625], [0.7816666666666666, 0.895625], [0.7816666666666666, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.933125]]}
#
#
# box = 0
#  rect_start = [112, 162]
#  width = 901
#  height = 2
#  opacity= 0.23005776098896624
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1525, 0.13875], [0.1525, 0.10125], [0.8441666666666666, 0.10125], [0.8441666666666666, 0.13875], [0.8183333333333334, 0.13875], [0.8183333333333334, 0.17625], [0.09333333333333334, 0.17625], [0.09333333333333334, 0.13875]]}
# box = 2
#  rect_start = [115, 644]
#  width = 903
#  height = 2
#  opacity= 0.22745572411369808
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.14333333333333334, 0.44], [0.14333333333333334, 0.4025], [0.8483333333333334, 0.4025], [0.8483333333333334, 0.44], [0.7825, 0.44], [0.7825, 0.4775], [0.09583333333333334, 0.4775], [0.09583333333333334, 0.44]]}
# box = 2
#  rect_start = [115, 764]
#  width = 903
#  height = 1
#  opacity= 0.372339369380256
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13333333333333333, 0.515], [0.13333333333333333, 0.4775], [0.8483333333333334, 0.4775], [0.8483333333333334, 0.4775], [0.8025, 0.4775], [0.8025, 0.515], [0.09583333333333334, 0.515], [0.09583333333333334, 0.515]]}
# box = 3
#  rect_start = [131, 1133]
#  width = 903
#  height = 2
#  opacity= 0.39744649087970985
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.15166666666666667, 0.745625], [0.15166666666666667, 0.708125], [0.8616666666666667, 0.708125], [0.8616666666666667, 0.745625], [0.8433333333333334, 0.745625], [0.8433333333333334, 0.783125], [0.10916666666666666, 0.783125], [0.10916666666666666, 0.745625]]}
# box = 3
#  rect_start = [131, 1373]
#  width = 903
#  height = 2
#  opacity= 0.48234133898113185
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13083333333333333, 0.895625], [0.13083333333333333, 0.858125], [0.8616666666666667, 0.858125], [0.8616666666666667, 0.895625], [0.8441666666666666, 0.895625], [0.8441666666666666, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.895625]]}
#
#
# box = 0
#  rect_start = [128, 433]
#  width = 940
#  height = 1
#  opacity= 0.5897483416313891
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1775, 0.3125], [0.1775, 0.270625], [0.89, 0.270625], [0.89, 0.270625], [0.84, 0.270625], [0.84, 0.3125], [0.10666666666666667, 0.3125], [0.10666666666666667, 0.3125]]}
# box = 0
#  rect_start = [128, 701]
#  width = 940
#  height = 8
#  opacity= 0.5341436124690999
# num_subboxes = 8
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.11833333333333333, 0.48], [0.11833333333333333, 0.438125], [0.89, 0.438125], [0.89, 0.73125], [0.8858333333333334, 0.73125], [0.8858333333333334, 0.773125], [0.10666666666666667, 0.773125], [0.10666666666666667, 0.48]]}
#
#
#
#
# box = 0
#  rect_start = [128, 634]
#  width = 940
#  height = 5
#  opacity= 0.4852788396795657
# num_subboxes = 5
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.19, 0.438125], [0.19, 0.39625], [0.89, 0.39625], [0.89, 0.56375], [0.8366666666666667, 0.56375], [0.8366666666666667, 0.605625], [0.10666666666666667, 0.605625], [0.10666666666666667, 0.438125]]}
# box = 0
#  rect_start = [128, 1103]
#  width = 940
#  height = 2
#  opacity= 0.21106917534040895
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.14416666666666667, 0.73125], [0.14416666666666667, 0.689375], [0.89, 0.689375], [0.89, 0.73125], [0.845, 0.73125], [0.845, 0.773125], [0.10666666666666667, 0.773125], [0.10666666666666667, 0.73125]]}
# box = 0
#  rect_start = [128, 1237]
#  width = 940
#  height = 1
#  opacity= 0.38512312712514707
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.18666666666666668, 0.815], [0.18666666666666668, 0.773125], [0.89, 0.773125], [0.89, 0.773125], [0.8483333333333334, 0.773125], [0.8483333333333334, 0.815], [0.10666666666666667, 0.815], [0.10666666666666667, 0.815]]}
#
#
# box = 0
#  rect_start = [128, 768]
#  width = 940
#  height = 6
#  opacity= 0.4806290662439598
# num_subboxes = 6
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1125, 0.521875], [0.1125, 0.48], [0.89, 0.48], [0.89, 0.689375], [0.8775, 0.689375], [0.8775, 0.73125], [0.10666666666666667, 0.73125], [0.10666666666666667, 0.521875]]}
# box = 0
#  rect_start = [128, 1237]
#  width = 940
#  height = 1
#  opacity= 0.2044078575984778
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.10916666666666666, 0.815], [0.10916666666666666, 0.773125], [0.89, 0.773125], [0.89, 0.773125], [0.86, 0.773125], [0.86, 0.815], [0.10666666666666667, 0.815], [0.10666666666666667, 0.815]]}
#
#
# box = 0
#  rect_start = [128, 1237]
#  width = 940
#  height = 1
#  opacity= 0.28431205555449146
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13583333333333333, 0.815], [0.13583333333333333, 0.773125], [0.89, 0.773125], [0.89, 0.773125], [0.8891666666666667, 0.773125], [0.8891666666666667, 0.815], [0.10666666666666667, 0.815], [0.10666666666666667, 0.815]]}
#
#
# box = 0
#  rect_start = [56, 95]
#  width = 466
#  height = 3
#  opacity= 0.5850220038645038
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.07833333333333334, 0.0775], [0.07833333333333334, 0.059375], [0.435, 0.059375], [0.435, 0.095625], [0.3933333333333333, 0.095625], [0.3933333333333333, 0.11375], [0.04666666666666667, 0.11375], [0.04666666666666667, 0.0775]]}
# box = 2
#  rect_start = [77, 440]
#  width = 469
#  height = 1
#  opacity= 0.5362717420740707
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.14333333333333334, 0.296875], [0.14333333333333334, 0.275], [0.455, 0.275], [0.455, 0.275], [0.4475, 0.275], [0.4475, 0.296875], [0.06416666666666666, 0.296875], [0.06416666666666666, 0.296875]]}
# box = 2
#  rect_start = [77, 510]
#  width = 469
#  height = 2
#  opacity= 0.2804770968620595
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.09083333333333334, 0.340625], [0.09083333333333334, 0.31875], [0.455, 0.31875], [0.455, 0.340625], [0.4033333333333333, 0.340625], [0.4033333333333333, 0.3625], [0.06416666666666666, 0.3625], [0.06416666666666666, 0.340625]]}
# box = 2
#  rect_start = [77, 580]
#  width = 469
#  height = 3
#  opacity= 0.5329611635430895
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.08333333333333333, 0.384375], [0.08333333333333333, 0.3625], [0.455, 0.3625], [0.455, 0.40625], [0.3825, 0.40625], [0.3825, 0.428125], [0.06416666666666666, 0.428125], [0.06416666666666666, 0.384375]]}
# box = 2
#  rect_start = [77, 685]
#  width = 469
#  height = 1
#  opacity= 0.41376952402399736
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13916666666666666, 0.45], [0.13916666666666666, 0.428125], [0.455, 0.428125], [0.455, 0.428125], [0.4175, 0.428125], [0.4175, 0.45], [0.06416666666666666, 0.45], [0.06416666666666666, 0.45]]}
# box = 5
#  rect_start = [56, 1408]
#  width = 504
#  height = 2
#  opacity= 0.5267049513276596
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.08166666666666667, 0.898125], [0.08166666666666667, 0.88], [0.4666666666666667, 0.88], [0.4666666666666667, 0.898125], [0.3858333333333333, 0.898125], [0.3858333333333333, 0.91625], [0.04666666666666667, 0.91625], [0.04666666666666667, 0.898125]]}
# box = 5
#  rect_start = [56, 1495]
#  width = 504
#  height = 1
#  opacity= 0.5441177886110198
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.04833333333333333, 0.9525], [0.04833333333333333, 0.934375], [0.4666666666666667, 0.934375], [0.4666666666666667, 0.934375], [0.4608333333333333, 0.934375], [0.4608333333333333, 0.9525], [0.04666666666666667, 0.9525], [0.04666666666666667, 0.9525]]}
# box = 7
#  rect_start = [594, 1144]
#  width = 499
#  height = 1
#  opacity= 0.4354469895662356
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5308333333333334, 0.733125], [0.5308333333333334, 0.715], [0.9108333333333334, 0.715], [0.9108333333333334, 0.715], [0.865, 0.715], [0.865, 0.733125], [0.495, 0.733125], [0.495, 0.733125]]}
# box = 7
#  rect_start = [594, 1173]
#  width = 499
#  height = 1
#  opacity= 0.5992355236184976
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.49916666666666665, 0.75125], [0.49916666666666665, 0.733125], [0.9108333333333334, 0.733125], [0.9108333333333334, 0.733125], [0.8775, 0.733125], [0.8775, 0.75125], [0.495, 0.75125], [0.495, 0.75125]]}
# box = 8
#  rect_start = [594, 1491]
#  width = 499
#  height = 2
#  opacity= 0.5475883771587725
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5183333333333333, 0.95], [0.5183333333333333, 0.931875], [0.9108333333333334, 0.931875], [0.9108333333333334, 0.95], [0.8641666666666666, 0.95], [0.8641666666666666, 0.968125], [0.495, 0.968125], [0.495, 0.95]]}
#
#
# box = 0
#  rect_start = [56, 66]
#  width = 466
#  height = 1
#  opacity= 0.2085158601370677
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.07166666666666667, 0.059375], [0.07166666666666667, 0.04125], [0.435, 0.04125], [0.435, 0.04125], [0.36083333333333334, 0.04125], [0.36083333333333334, 0.059375], [0.04666666666666667, 0.059375], [0.04666666666666667, 0.059375]]}
# box = 0
#  rect_start = [56, 153]
#  width = 466
#  height = 1
#  opacity= 0.2897793805769983
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.09916666666666667, 0.11375], [0.09916666666666667, 0.095625], [0.435, 0.095625], [0.435, 0.095625], [0.43333333333333335, 0.095625], [0.43333333333333335, 0.11375], [0.04666666666666667, 0.11375], [0.04666666666666667, 0.11375]]}
# box = 2
#  rect_start = [77, 545]
#  width = 469
#  height = 5
#  opacity= 0.546296916686145
# num_subboxes = 5
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.08666666666666667, 0.3625], [0.08666666666666667, 0.340625], [0.455, 0.340625], [0.455, 0.428125], [0.375, 0.428125], [0.375, 0.45], [0.06416666666666666, 0.45], [0.06416666666666666, 0.3625]]}
# box = 3
#  rect_start = [56, 953]
#  width = 483
#  height = 1
#  opacity= 0.21983186969957488
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.07083333333333333, 0.61375], [0.07083333333333333, 0.595625], [0.44916666666666666, 0.595625], [0.44916666666666666, 0.595625], [0.3825, 0.595625], [0.3825, 0.61375], [0.04666666666666667, 0.61375], [0.04666666666666667, 0.61375]]}
# box = 3
#  rect_start = [56, 982]
#  width = 483
#  height = 2
#  opacity= 0.44023153553812755
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.07333333333333333, 0.631875], [0.07333333333333333, 0.61375], [0.44916666666666666, 0.61375], [0.44916666666666666, 0.631875], [0.4475, 0.631875], [0.4475, 0.65], [0.04666666666666667, 0.65], [0.04666666666666667, 0.631875]]}
# box = 5
#  rect_start = [56, 1437]
#  width = 504
#  height = 2
#  opacity= 0.212462962151506
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.09, 0.91625], [0.09, 0.898125], [0.4666666666666667, 0.898125], [0.4666666666666667, 0.91625], [0.3975, 0.91625], [0.3975, 0.934375], [0.04666666666666667, 0.934375], [0.04666666666666667, 0.91625]]}
# box = 5
#  rect_start = [56, 1495]
#  width = 504
#  height = 1
#  opacity= 0.4192932120977379
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.05416666666666667, 0.9525], [0.05416666666666667, 0.934375], [0.4666666666666667, 0.934375], [0.4666666666666667, 0.934375], [0.44333333333333336, 0.934375], [0.44333333333333336, 0.9525], [0.04666666666666667, 0.9525], [0.04666666666666667, 0.9525]]}
# box = 6
#  rect_start = [594, 1035]
#  width = 499
#  height = 1
#  opacity= 0.32592655047234376
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5208333333333334, 0.665], [0.5208333333333334, 0.646875], [0.9108333333333334, 0.646875], [0.9108333333333334, 0.646875], [0.8758333333333334, 0.646875], [0.8758333333333334, 0.665], [0.495, 0.665], [0.495, 0.665]]}
# box = 8
#  rect_start = [594, 1520]
#  width = 499
#  height = 1
#  opacity= 0.5702867792177674
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5425, 0.968125], [0.5425, 0.95], [0.9108333333333334, 0.95], [0.9108333333333334, 0.95], [0.8275, 0.95], [0.8275, 0.968125], [0.495, 0.968125], [0.495, 0.968125]]}
#
#
# box = 0
#  rect_start = [56, 95]
#  width = 466
#  height = 1
#  opacity= 0.3976800937432937
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.055, 0.0775], [0.055, 0.059375], [0.435, 0.059375], [0.435, 0.059375], [0.39166666666666666, 0.059375], [0.39166666666666666, 0.0775], [0.04666666666666667, 0.0775], [0.04666666666666667, 0.0775]]}
# box = 0
#  rect_start = [56, 153]
#  width = 466
#  height = 1
#  opacity= 0.2529511020031484
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.06, 0.11375], [0.06, 0.095625], [0.435, 0.095625], [0.435, 0.095625], [0.43166666666666664, 0.095625], [0.43166666666666664, 0.11375], [0.04666666666666667, 0.11375], [0.04666666666666667, 0.11375]]}
# box = 2
#  rect_start = [77, 440]
#  width = 469
#  height = 1
#  opacity= 0.37990148586242634
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.07166666666666667, 0.296875], [0.07166666666666667, 0.275], [0.455, 0.275], [0.455, 0.275], [0.37666666666666665, 0.275], [0.37666666666666665, 0.296875], [0.06416666666666666, 0.296875], [0.06416666666666666, 0.296875]]}
# box = 2
#  rect_start = [77, 615]
#  width = 469
#  height = 2
#  opacity= 0.2706889048477029
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13583333333333333, 0.40625], [0.13583333333333333, 0.384375], [0.455, 0.384375], [0.455, 0.40625], [0.3858333333333333, 0.40625], [0.3858333333333333, 0.428125], [0.06416666666666666, 0.428125], [0.06416666666666666, 0.40625]]}
# box = 2
#  rect_start = [77, 685]
#  width = 469
#  height = 1
#  opacity= 0.4076539882369525
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.14416666666666667, 0.45], [0.14416666666666667, 0.428125], [0.455, 0.428125], [0.455, 0.428125], [0.43666666666666665, 0.428125], [0.43666666666666665, 0.45], [0.06416666666666666, 0.45], [0.06416666666666666, 0.45]]}
# box = 3
#  rect_start = [56, 895]
#  width = 483
#  height = 2
#  opacity= 0.31145148319304916
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.07666666666666666, 0.5775], [0.07666666666666666, 0.559375], [0.44916666666666666, 0.559375], [0.44916666666666666, 0.5775], [0.4216666666666667, 0.5775], [0.4216666666666667, 0.595625], [0.04666666666666667, 0.595625], [0.04666666666666667, 0.5775]]}
# box = 3
#  rect_start = [56, 982]
#  width = 483
#  height = 2
#  opacity= 0.30522261287827435
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.058333333333333334, 0.631875], [0.058333333333333334, 0.61375], [0.44916666666666666, 0.61375], [0.44916666666666666, 0.631875], [0.37333333333333335, 0.631875], [0.37333333333333335, 0.65], [0.04666666666666667, 0.65], [0.04666666666666667, 0.631875]]}
# box = 6
#  rect_start = [594, 890]
#  width = 499
#  height = 5
#  opacity= 0.29836549203656515
# num_subboxes = 5
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.565, 0.574375], [0.565, 0.55625], [0.9108333333333334, 0.55625], [0.9108333333333334, 0.62875], [0.8441666666666666, 0.62875], [0.8441666666666666, 0.646875], [0.495, 0.646875], [0.495, 0.574375]]}
# box = 7
#  rect_start = [594, 1115]
#  width = 499
#  height = 2
#  opacity= 0.3163720943567868
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5466666666666666, 0.715], [0.5466666666666666, 0.696875], [0.9108333333333334, 0.696875], [0.9108333333333334, 0.715], [0.8475, 0.715], [0.8475, 0.733125], [0.495, 0.733125], [0.495, 0.715]]}
# box = 7
#  rect_start = [594, 1173]
#  width = 499
#  height = 1
#  opacity= 0.28852401844413783
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5308333333333334, 0.75125], [0.5308333333333334, 0.733125], [0.9108333333333334, 0.733125], [0.9108333333333334, 0.733125], [0.8433333333333334, 0.733125], [0.8433333333333334, 0.75125], [0.495, 0.75125], [0.495, 0.75125]]}
# box = 8
#  rect_start = [594, 1462]
#  width = 499
#  height = 3
#  opacity= 0.5940869187027005
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5, 0.931875], [0.5, 0.91375], [0.9108333333333334, 0.91375], [0.9108333333333334, 0.95], [0.8558333333333333, 0.95], [0.8558333333333333, 0.968125], [0.495, 0.968125], [0.495, 0.931875]]}
#
#
# box = 2
#  rect_start = [77, 475]
#  width = 469
#  height = 7
#  opacity= 0.48884514779892335
# num_subboxes = 7
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1425, 0.31875], [0.1425, 0.296875], [0.455, 0.296875], [0.455, 0.428125], [0.4266666666666667, 0.428125], [0.4266666666666667, 0.45], [0.06416666666666666, 0.45], [0.06416666666666666, 0.31875]]}
# box = 3
#  rect_start = [56, 924]
#  width = 483
#  height = 3
#  opacity= 0.5485711664127462
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.0625, 0.595625], [0.0625, 0.5775], [0.44916666666666666, 0.5775], [0.44916666666666666, 0.61375], [0.44583333333333336, 0.61375], [0.44583333333333336, 0.631875], [0.04666666666666667, 0.631875], [0.04666666666666667, 0.595625]]}
# box = 3
#  rect_start = [56, 1011]
#  width = 483
#  height = 1
#  opacity= 0.3187004092859723
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.060833333333333336, 0.65], [0.060833333333333336, 0.631875], [0.44916666666666666, 0.631875], [0.44916666666666666, 0.631875], [0.37, 0.631875], [0.37, 0.65], [0.04666666666666667, 0.65], [0.04666666666666667, 0.65]]}
# box = 4
#  rect_start = [56, 1126]
#  width = 483
#  height = 3
#  opacity= 0.5708318374954588
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.11083333333333334, 0.721875], [0.11083333333333334, 0.70375], [0.44916666666666666, 0.70375], [0.44916666666666666, 0.74], [0.4225, 0.74], [0.4225, 0.758125], [0.04666666666666667, 0.758125], [0.04666666666666667, 0.721875]]}
# box = 5
#  rect_start = [56, 1321]
#  width = 504
#  height = 3
#  opacity= 0.5711517995376607
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.11416666666666667, 0.84375], [0.11416666666666667, 0.825625], [0.4666666666666667, 0.825625], [0.4666666666666667, 0.861875], [0.4075, 0.861875], [0.4075, 0.88], [0.04666666666666667, 0.88], [0.04666666666666667, 0.84375]]}
# box = 5
#  rect_start = [56, 1495]
#  width = 504
#  height = 1
#  opacity= 0.4673987654126577
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1075, 0.9525], [0.1075, 0.934375], [0.4666666666666667, 0.934375], [0.4666666666666667, 0.934375], [0.385, 0.934375], [0.385, 0.9525], [0.04666666666666667, 0.9525], [0.04666666666666667, 0.9525]]}
#
#
# box = 0
#  rect_start = [56, 124]
#  width = 466
#  height = 2
#  opacity= 0.29630915689511633
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1175, 0.095625], [0.1175, 0.0775], [0.435, 0.0775], [0.435, 0.095625], [0.385, 0.095625], [0.385, 0.11375], [0.04666666666666667, 0.11375], [0.04666666666666667, 0.095625]]}
# box = 1
#  rect_start = [56, 298]
#  width = 494
#  height = 2
#  opacity= 0.4913966012718616
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.065, 0.204375], [0.065, 0.18625], [0.4583333333333333, 0.18625], [0.4583333333333333, 0.204375], [0.4558333333333333, 0.204375], [0.4558333333333333, 0.2225], [0.04666666666666667, 0.2225], [0.04666666666666667, 0.204375]]}
# box = 3
#  rect_start = [56, 866]
#  width = 483
#  height = 6
#  opacity= 0.30966953225514415
# num_subboxes = 6
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.07583333333333334, 0.559375], [0.07583333333333334, 0.54125], [0.44916666666666666, 0.54125], [0.44916666666666666, 0.631875], [0.38083333333333336, 0.631875], [0.38083333333333336, 0.65], [0.04666666666666667, 0.65], [0.04666666666666667, 0.559375]]}
# box = 4
#  rect_start = [56, 1126]
#  width = 483
#  height = 3
#  opacity= 0.22459336240576178
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.0475, 0.721875], [0.0475, 0.70375], [0.44916666666666666, 0.70375], [0.44916666666666666, 0.74], [0.37833333333333335, 0.74], [0.37833333333333335, 0.758125], [0.04666666666666667, 0.758125], [0.04666666666666667, 0.721875]]}
# box = 5
#  rect_start = [56, 1495]
#  width = 504
#  height = 1
#  opacity= 0.43645941205807004
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.058333333333333334, 0.9525], [0.058333333333333334, 0.934375], [0.4666666666666667, 0.934375], [0.4666666666666667, 0.934375], [0.4575, 0.934375], [0.4575, 0.9525], [0.04666666666666667, 0.9525], [0.04666666666666667, 0.9525]]}
# box = 6
#  rect_start = [594, 919]
#  width = 499
#  height = 1
#  opacity= 0.42601598297220755
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.535, 0.5925], [0.535, 0.574375], [0.9108333333333334, 0.574375], [0.9108333333333334, 0.574375], [0.8358333333333333, 0.574375], [0.8358333333333333, 0.5925], [0.495, 0.5925], [0.495, 0.5925]]}
# box = 7
#  rect_start = [594, 1144]
#  width = 499
#  height = 2
#  opacity= 0.5326921766116459
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5766666666666667, 0.733125], [0.5766666666666667, 0.715], [0.9108333333333334, 0.715], [0.9108333333333334, 0.733125], [0.8425, 0.733125], [0.8425, 0.75125], [0.495, 0.75125], [0.495, 0.733125]]}
# box = 8
#  rect_start = [594, 1520]
#  width = 499
#  height = 1
#  opacity= 0.4255077701148693
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.545, 0.968125], [0.545, 0.95], [0.9108333333333334, 0.95], [0.9108333333333334, 0.95], [0.8966666666666666, 0.95], [0.8966666666666666, 0.968125], [0.495, 0.968125], [0.495, 0.968125]]}
