# %%
import cv2
import numpy as np
import random
import torch
from PIL import Image
import json
import os

random.seed(42)

# %%
def image_preprocess(image_path, resized_height=1600, resized_width=1200):
    #resize img
    image = cv2.imread(image_path)
    overlay_image = cv2.resize(image, (resized_width, resized_height))

    # black background overlay
    resized_dimension = resized_height
    black_background = np.zeros((resized_dimension, resized_dimension, 3), dtype=np.uint8)
    overlay_height, overlay_width = overlay_image.shape[:2]
    black_background[0:overlay_height, 0:overlay_width] = overlay_image

    return black_background

# %%
def add_random_offset(point, max_offset):
        return point + random.randint(-max_offset, max_offset)

# %%
def random_rgb_color():
    r = random.randint(0, 175)
    g = random.randint(0, 175)
    b = random.randint(0, 175)
    return (r, g, b)

# %%
def draw_broken_box_with_subboxes(background, rect_start, width, height_in_lines, thickness, delta, l1, l2, max_offset=10, color=(0, 255, 0), opacity=0.5):
    """
    Draw a rectangular box broken into smaller subboxes with slight irregularities in width and height.
    
    Parameters:
        background (OpenCV Image): OpenCV Matrix representing the (already resized) image.
        rect_start (tuple): Starting coordinate (x, y) of the rectangle (top-left corner).
        width (int): Width of the overall rectangle.
        height (int): Height of the overall rectangle.
        thickness (int): Height of each smaller subbox.
        delta (int): Reduction in height for each smaller subbox.
        max_offset (int): Maximum random offset for width irregularity (in pixels).
        color (tuple): Color of the rectangle (BGR format).
        opacity (float): Opacity of the shape (0: fully transparent, 1: fully opaque).
        
    Returns:
        result_img (ndarray): Image with the broken box and irregular subboxes.
        bbox (dict): Metadata of the bounding box for YOLO.
    """
    # height in pixels
    height_in_pixels = height_in_lines*thickness
    
    # Create an overlay image (same size as the background)
    overlay = background.copy()

    # Define the top-left starting point of the rectangle
    x, y = rect_start
    
    # Number of subboxes along the height
    num_subboxes = height_in_lines
    print(f"num_subboxes = {num_subboxes}")
    img_height, img_width, _ = overlay.shape
    print(f"img_width = {img_width}, img_height = {img_height}")
    # Initialize the bounding box metadata
    # every object in the labels file has the following line: <class-index> <x1> <y1> <x2> <y2> ... <xn> <yn>.
    # it is not necessary that each object segment has the same number of x,y points
    # However, there should be minimum of 3 x,y points for each object
    # in our case, the segmenting polygon of a highlight will be defined using 8 coordinates
    
    bbox = {
        "class": 0,                                            # Assuming class 0 for YOLO
        "poly": [
            [(x+l1)/img_width, (y+thickness)/img_height],
            [(x+l1)/img_width, y/img_height],
            [(x+width)/img_width, y/img_height],
            [(x+width)/img_width, (y+height_in_pixels-thickness)/img_height],
            [(x+width-l2)/img_width, (y+height_in_pixels-thickness)/img_height],
            [(x+width-l2)/img_width, (y+height_in_pixels)/img_height],
            [x/img_width, (y+height_in_pixels)/img_height],
            [x/img_width, (y+thickness)/img_height]
        ]
        #"x_center": (x + width / 2) / background.shape[1],  # Normalize x center
        #"y_center": (y + height_in_pixels / 2) / background.shape[0],  # Normalize y center
        #"width": width / background.shape[1],                # Normalize width
        #"height": height_in_pixels / background.shape[0],              # Normalize height
    }
    

    # Iterate over each subbox to create the broken box pattern
    for i in range(num_subboxes):
        # Starting Y position of the current subbox
        subbox_start_y = y + i * thickness
        # Ending Y position of the current subbox (apply delta to reduce height)
        subbox_end_y = subbox_start_y + thickness - delta
            
        # Apply random width variation
        random_width_start = add_random_offset(x, max_offset)
        random_width_end = add_random_offset(x + width, max_offset)

        # Using half of random width offset as the random height offset
        random_height_offset = max_offset//2

        if(i == 0):
            random_width_start += l1
        elif(i == num_subboxes-1):
            random_width_end -= l2
        
        # Define the points of the subbox (irregular rectangle)
        pts = np.array([
            [add_random_offset(random_width_start, max_offset), add_random_offset(subbox_start_y, random_height_offset)],  # Top-left
            [add_random_offset(random_width_end, max_offset), add_random_offset(subbox_start_y, random_height_offset)],    # Top-right
            [add_random_offset(random_width_end, max_offset), add_random_offset(subbox_end_y, random_height_offset)],      # Bottom-right
            [add_random_offset(random_width_start, max_offset), add_random_offset(subbox_end_y, random_height_offset)]     # Bottom-left
        ], np.int32)
        
        # Draw the subbox on the overlay
        cv2.fillPoly(overlay, [pts], color)
    
    # Perform alpha blending (opacity) between the background and overlay
    result_img = cv2.addWeighted(overlay, opacity, background, 1 - opacity, 0)

    return result_img, bbox

# %%
training_custom_metadata = './background_images/train/metadata_train.json'

with open(training_custom_metadata, 'r') as f:
    metadata = json.load(f)

# %%
import math
training_dataset_path = "./background_images/train"
training_bbox_data = './generated_dataset/labels/train/'
generated_train_dataset_path = "./generated_dataset/images/train/"
variations_per_image = 15

for image in metadata["images"]:
    image_filename = image["filename"]
    image_path = os.path.join(training_dataset_path, image_filename)
    # bg_img = image_preprocess(image_path, 1600)
    bg_img = cv2.imread(image_path)
    intermediate_img = bg_img

    # Save each variation with a unique filename
    filename, extension = os.path.splitext(image_filename)
    
    for var in range(variations_per_image):
        intermediate_img = bg_img

        # create a path string representing a fresh file for this image variation
        result_image_name = f"{filename}_variation{var}{extension}"
        result_metadata_name = f"{filename}_variation{var}.txt"
        training_bbox_data_file = f"{training_bbox_data}{result_metadata_name}"

        # flush previous contents if present
        with open(training_bbox_data_file,"w") as f:
            f.write("")
        
        with open(training_bbox_data_file, "a") as f:
            for box_num, box in enumerate(image["boxes"]):
                # 10% chance there is no highlight in this paragraph/box
                is_not_highlighted = random.randint(0, 9)
                if(is_not_highlighted<1):
                    continue
                
                # Get initial box parameters
                original_rect_start = box["rect_start"][:]
                width = box["width"]
                height = box["height"]
                thickness = box["thickness"]
                delta = box["line_spacing"]
                
                start_line = 0 # absolute line number from where highlight begins 
                max_lines = round(height // thickness, 0)
                lines_left_in_box = max_lines
                
                while lines_left_in_box>0:  
                    # 20% chance there is no highlight in the rest of the box
                    is_not_highlighted = random.randint(1, 10)
                    if(is_not_highlighted < 3):
                        lines_left_in_box = 0
                        continue
                        
                    # else, set random starting position within the remaining rectangle bounds
                    if(start_line == max_lines-1):
                        random_line_for_highlight_start = start_line
                    else:
                        random_line_for_highlight_start = random.randint(start_line, max_lines-1) # measured in number of lines, not pixels.
                    
                    lines_left_in_box = max_lines - random_line_for_highlight_start
                    variation_rect_start = original_rect_start[:]
                    variation_rect_start[1] += thickness*random_line_for_highlight_start
                    highlight_height =  random.randint(1, lines_left_in_box) # height of highlight-box in number of lines
                    
                    # new values for start_line and lines_left_in_box
                    start_line = random_line_for_highlight_start + highlight_height
                    lines_left_in_box = max_lines - start_line
    
                    # Ensure the rectangle is within the image bounds
                    #variation_rect_start[1] = min(variation_rect_start[1], resized_img_height - adjusted_height)
                    
                    l1, l2 = random.randint(0, 100), random.randint(0, 100)
                    max_offset = random.randint(0, 10)
                    color = random_rgb_color()
                    opacity = random.uniform(0.2, 0.6)
    
                    print(f"box = {box_num} \n rect_start = {variation_rect_start}\n width = {width} \n height = {highlight_height} \n opacity= {opacity}")
                    # Draw the adjusted rectangle
                    intermediate_img, bbox_metadata = draw_broken_box_with_subboxes(
                        intermediate_img, variation_rect_start, width, highlight_height, thickness, delta, l1, l2, max_offset, color, opacity
                    )

                    # create line to be appended to the image label file
                    line_to_be_appended = f"{bbox_metadata['class']} "
                    spaces=0
                    print(bbox_metadata)
                    for coord in bbox_metadata["poly"]:
                        line_to_be_appended = line_to_be_appended + f"{coord[0]} {coord[1]}"
                        if(spaces<8):
                            line_to_be_appended = line_to_be_appended + " "
                        spaces += 1
                    # append that line to the image path
                    f.write(f"{line_to_be_appended}\n")
                    
            result_image_filepath = os.path.join(generated_train_dataset_path, result_image_name)
            print(f"\n")

            (h, w) = intermediate_img.shape[:2]
            center = (w // 2, h // 2)
            degree_to_rotate = np.random.uniform(-2, 2)
            rotation_matrix = cv2.getRotationMatrix2D(center, degree_to_rotate, 1)
            rotated_image = cv2.warpAffine(intermediate_img, rotation_matrix, (w, h))
            
            cv2.imwrite(result_image_filepath, rotated_image)
            #json.dump(bbox_metadata, f)  # Append the JSON object (box) to the file
            f.write("\n")  # Write each box on a new line
# Out:
# box = 1
#  rect_start = [113, 345]
#  width = 903
#  height = 1
#  opacity= 0.3687687278741082
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1725, 0.253125], [0.1725, 0.215625], [0.8466666666666667, 0.215625], [0.8466666666666667, 0.215625], [0.8358333333333333, 0.215625], [0.8358333333333333, 0.253125], [0.09416666666666666, 0.253125], [0.09416666666666666, 0.253125]]}
# box = 1
#  rect_start = [113, 405]
#  width = 903
#  height = 1
#  opacity= 0.47925575799529074
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1175, 0.290625], [0.1175, 0.253125], [0.8466666666666667, 0.253125], [0.8466666666666667, 0.253125], [0.7991666666666667, 0.253125], [0.7991666666666667, 0.290625], [0.09416666666666666, 0.290625], [0.09416666666666666, 0.290625]]}
# box = 2
#  rect_start = [115, 644]
#  width = 903
#  height = 1
#  opacity= 0.4208162525092908
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.17333333333333334, 0.44], [0.17333333333333334, 0.4025], [0.8483333333333334, 0.4025], [0.8483333333333334, 0.4025], [0.8, 0.4025], [0.8, 0.44], [0.09583333333333334, 0.44], [0.09583333333333334, 0.44]]}
# box = 2
#  rect_start = [115, 764]
#  width = 903
#  height = 1
#  opacity= 0.4807281253834205
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1125, 0.515], [0.1125, 0.4775], [0.8483333333333334, 0.4775], [0.8483333333333334, 0.4775], [0.8091666666666667, 0.4775], [0.8091666666666667, 0.515], [0.09583333333333334, 0.515], [0.09583333333333334, 0.515]]}
# box = 3
#  rect_start = [131, 1373]
#  width = 903
#  height = 1
#  opacity= 0.3604659148089316
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.18166666666666667, 0.895625], [0.18166666666666667, 0.858125], [0.8616666666666667, 0.858125], [0.8616666666666667, 0.858125], [0.8275, 0.858125], [0.8275, 0.895625], [0.10916666666666666, 0.895625], [0.10916666666666666, 0.895625]]}
# box = 3
#  rect_start = [131, 1433]
#  width = 903
#  height = 1
#  opacity= 0.28772830366291335
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.18833333333333332, 0.933125], [0.18833333333333332, 0.895625], [0.8616666666666667, 0.895625], [0.8616666666666667, 0.895625], [0.8, 0.895625], [0.8, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.933125]]}
#
#
# box = 0
#  rect_start = [112, 162]
#  width = 901
#  height = 2
#  opacity= 0.5443118808937992
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13333333333333333, 0.13875], [0.13333333333333333, 0.10125], [0.8441666666666666, 0.10125], [0.8441666666666666, 0.13875], [0.7808333333333334, 0.13875], [0.7808333333333334, 0.17625], [0.09333333333333334, 0.17625], [0.09333333333333334, 0.13875]]}
# box = 1
#  rect_start = [113, 345]
#  width = 903
#  height = 1
#  opacity= 0.2611357074198539
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.16083333333333333, 0.253125], [0.16083333333333333, 0.215625], [0.8466666666666667, 0.215625], [0.8466666666666667, 0.215625], [0.815, 0.215625], [0.815, 0.253125], [0.09416666666666666, 0.253125], [0.09416666666666666, 0.253125]]}
# box = 1
#  rect_start = [113, 405]
#  width = 903
#  height = 1
#  opacity= 0.5264093013680353
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1, 0.290625], [0.1, 0.253125], [0.8466666666666667, 0.253125], [0.8466666666666667, 0.253125], [0.8216666666666667, 0.253125], [0.8216666666666667, 0.290625], [0.09416666666666666, 0.290625], [0.09416666666666666, 0.290625]]}
# box = 2
#  rect_start = [115, 644]
#  width = 903
#  height = 2
#  opacity= 0.2484016783473063
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.16666666666666666, 0.44], [0.16666666666666666, 0.4025], [0.8483333333333334, 0.4025], [0.8483333333333334, 0.44], [0.7791666666666667, 0.44], [0.7791666666666667, 0.4775], [0.09583333333333334, 0.4775], [0.09583333333333334, 0.44]]}
# box = 2
#  rect_start = [115, 764]
#  width = 903
#  height = 1
#  opacity= 0.2971988969582898
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.11833333333333333, 0.515], [0.11833333333333333, 0.4775], [0.8483333333333334, 0.4775], [0.8483333333333334, 0.4775], [0.7908333333333334, 0.4775], [0.7908333333333334, 0.515], [0.09583333333333334, 0.515], [0.09583333333333334, 0.515]]}
#
#
# box = 1
#  rect_start = [113, 345]
#  width = 903
#  height = 1
#  opacity= 0.27339521431489333
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.11416666666666667, 0.253125], [0.11416666666666667, 0.215625], [0.8466666666666667, 0.215625], [0.8466666666666667, 0.215625], [0.8266666666666667, 0.215625], [0.8266666666666667, 0.253125], [0.09416666666666666, 0.253125], [0.09416666666666666, 0.253125]]}
# box = 1
#  rect_start = [113, 405]
#  width = 903
#  height = 1
#  opacity= 0.2008621513405706
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.145, 0.290625], [0.145, 0.253125], [0.8466666666666667, 0.253125], [0.8466666666666667, 0.253125], [0.8241666666666667, 0.253125], [0.8241666666666667, 0.290625], [0.09416666666666666, 0.290625], [0.09416666666666666, 0.290625]]}
# box = 2
#  rect_start = [115, 584]
#  width = 903
#  height = 2
#  opacity= 0.4991902241516256
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.12666666666666668, 0.4025], [0.12666666666666668, 0.365], [0.8483333333333334, 0.365], [0.8483333333333334, 0.4025], [0.8258333333333333, 0.4025], [0.8258333333333333, 0.44], [0.09583333333333334, 0.44], [0.09583333333333334, 0.4025]]}
# box = 2
#  rect_start = [115, 764]
#  width = 903
#  height = 1
#  opacity= 0.5716073326822056
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.10916666666666666, 0.515], [0.10916666666666666, 0.4775], [0.8483333333333334, 0.4775], [0.8483333333333334, 0.4775], [0.7775, 0.4775], [0.7775, 0.515], [0.09583333333333334, 0.515], [0.09583333333333334, 0.515]]}
# box = 3
#  rect_start = [131, 1193]
#  width = 903
#  height = 1
#  opacity= 0.48141597003494835
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.135, 0.783125], [0.135, 0.745625], [0.8616666666666667, 0.745625], [0.8616666666666667, 0.745625], [0.8225, 0.745625], [0.8225, 0.783125], [0.10916666666666666, 0.783125], [0.10916666666666666, 0.783125]]}
# box = 3
#  rect_start = [131, 1373]
#  width = 903
#  height = 2
#  opacity= 0.5411651261567589
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.17333333333333334, 0.895625], [0.17333333333333334, 0.858125], [0.8616666666666667, 0.858125], [0.8616666666666667, 0.895625], [0.84, 0.895625], [0.84, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.895625]]}
#
#
# box = 0
#  rect_start = [112, 162]
#  width = 901
#  height = 2
#  opacity= 0.32330333997205346
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.155, 0.13875], [0.155, 0.10125], [0.8441666666666666, 0.10125], [0.8441666666666666, 0.13875], [0.7858333333333334, 0.13875], [0.7858333333333334, 0.17625], [0.09333333333333334, 0.17625], [0.09333333333333334, 0.13875]]}
# box = 1
#  rect_start = [113, 345]
#  width = 903
#  height = 1
#  opacity= 0.33986336977836745
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13416666666666666, 0.253125], [0.13416666666666666, 0.215625], [0.8466666666666667, 0.215625], [0.8466666666666667, 0.215625], [0.8433333333333334, 0.215625], [0.8433333333333334, 0.253125], [0.09416666666666666, 0.253125], [0.09416666666666666, 0.253125]]}
# box = 1
#  rect_start = [113, 405]
#  width = 903
#  height = 1
#  opacity= 0.47180724734410545
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.17583333333333334, 0.290625], [0.17583333333333334, 0.253125], [0.8466666666666667, 0.253125], [0.8466666666666667, 0.253125], [0.8175, 0.253125], [0.8175, 0.290625], [0.09416666666666666, 0.290625], [0.09416666666666666, 0.290625]]}
# box = 2
#  rect_start = [115, 644]
#  width = 903
#  height = 3
#  opacity= 0.3540781733378909
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.17916666666666667, 0.44], [0.17916666666666667, 0.4025], [0.8483333333333334, 0.4025], [0.8483333333333334, 0.4775], [0.815, 0.4775], [0.815, 0.515], [0.09583333333333334, 0.515], [0.09583333333333334, 0.44]]}
# box = 3
#  rect_start = [131, 1253]
#  width = 903
#  height = 3
#  opacity= 0.4709271781090932
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1675, 0.820625], [0.1675, 0.783125], [0.8616666666666667, 0.783125], [0.8616666666666667, 0.858125], [0.8483333333333334, 0.858125], [0.8483333333333334, 0.895625], [0.10916666666666666, 0.895625], [0.10916666666666666, 0.820625]]}
# box = 3
#  rect_start = [131, 1433]
#  width = 903
#  height = 1
#  opacity= 0.5226251578305063
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.11833333333333333, 0.933125], [0.11833333333333333, 0.895625], [0.8616666666666667, 0.895625], [0.8616666666666667, 0.895625], [0.7816666666666666, 0.895625], [0.7816666666666666, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.933125]]}
#
#
# box = 0
#  rect_start = [112, 222]
#  width = 901
#  height = 1
#  opacity= 0.51136816270693
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13583333333333333, 0.17625], [0.13583333333333333, 0.13875], [0.8441666666666666, 0.13875], [0.8441666666666666, 0.13875], [0.8183333333333334, 0.13875], [0.8183333333333334, 0.17625], [0.09333333333333334, 0.17625], [0.09333333333333334, 0.17625]]}
# box = 1
#  rect_start = [113, 405]
#  width = 903
#  height = 1
#  opacity= 0.5588832412933049
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.15916666666666668, 0.290625], [0.15916666666666668, 0.253125], [0.8466666666666667, 0.253125], [0.8466666666666667, 0.253125], [0.77, 0.253125], [0.77, 0.290625], [0.09416666666666666, 0.290625], [0.09416666666666666, 0.290625]]}
# box = 2
#  rect_start = [115, 584]
#  width = 903
#  height = 3
#  opacity= 0.2925045918912747
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13083333333333333, 0.4025], [0.13083333333333333, 0.365], [0.8483333333333334, 0.365], [0.8483333333333334, 0.44], [0.815, 0.44], [0.815, 0.4775], [0.09583333333333334, 0.4775], [0.09583333333333334, 0.4025]]}
# box = 2
#  rect_start = [115, 764]
#  width = 903
#  height = 1
#  opacity= 0.42575679320990967
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.10916666666666666, 0.515], [0.10916666666666666, 0.4775], [0.8483333333333334, 0.4775], [0.8483333333333334, 0.4775], [0.7825, 0.4775], [0.7825, 0.515], [0.09583333333333334, 0.515], [0.09583333333333334, 0.515]]}
# box = 3
#  rect_start = [131, 1193]
#  width = 903
#  height = 3
#  opacity= 0.3881227344852187
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.19, 0.783125], [0.19, 0.745625], [0.8616666666666667, 0.745625], [0.8616666666666667, 0.820625], [0.8216666666666667, 0.820625], [0.8216666666666667, 0.858125], [0.10916666666666666, 0.858125], [0.10916666666666666, 0.783125]]}
# box = 3
#  rect_start = [131, 1373]
#  width = 903
#  height = 1
#  opacity= 0.5184908866400848
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.12, 0.895625], [0.12, 0.858125], [0.8616666666666667, 0.858125], [0.8616666666666667, 0.858125], [0.7875, 0.858125], [0.7875, 0.895625], [0.10916666666666666, 0.895625], [0.10916666666666666, 0.895625]]}
# box = 3
#  rect_start = [131, 1433]
#  width = 903
#  height = 1
#  opacity= 0.2704547844344237
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.155, 0.933125], [0.155, 0.895625], [0.8616666666666667, 0.895625], [0.8616666666666667, 0.895625], [0.8233333333333334, 0.895625], [0.8233333333333334, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.933125]]}
#
#
# box = 0
#  rect_start = [112, 162]
#  width = 901
#  height = 2
#  opacity= 0.3515957216513056
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.14083333333333334, 0.13875], [0.14083333333333334, 0.10125], [0.8441666666666666, 0.10125], [0.8441666666666666, 0.13875], [0.8183333333333334, 0.13875], [0.8183333333333334, 0.17625], [0.09333333333333334, 0.17625], [0.09333333333333334, 0.13875]]}
# box = 1
#  rect_start = [113, 405]
#  width = 903
#  height = 1
#  opacity= 0.37926981983462826
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.15333333333333332, 0.290625], [0.15333333333333332, 0.253125], [0.8466666666666667, 0.253125], [0.8466666666666667, 0.253125], [0.7658333333333334, 0.253125], [0.7658333333333334, 0.290625], [0.09416666666666666, 0.290625], [0.09416666666666666, 0.290625]]}
# box = 2
#  rect_start = [115, 764]
#  width = 903
#  height = 1
#  opacity= 0.3083665707904785
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.14083333333333334, 0.515], [0.14083333333333334, 0.4775], [0.8483333333333334, 0.4775], [0.8483333333333334, 0.4775], [0.7691666666666667, 0.4775], [0.7691666666666667, 0.515], [0.09583333333333334, 0.515], [0.09583333333333334, 0.515]]}
# box = 3
#  rect_start = [131, 1373]
#  width = 903
#  height = 2
#  opacity= 0.32090703551217425
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.11916666666666667, 0.895625], [0.11916666666666667, 0.858125], [0.8616666666666667, 0.858125], [0.8616666666666667, 0.895625], [0.8416666666666667, 0.895625], [0.8416666666666667, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.895625]]}
#
#
# box = 1
#  rect_start = [113, 345]
#  width = 903
#  height = 1
#  opacity= 0.24738062488458465
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.11, 0.253125], [0.11, 0.215625], [0.8466666666666667, 0.215625], [0.8466666666666667, 0.215625], [0.8308333333333333, 0.215625], [0.8308333333333333, 0.253125], [0.09416666666666666, 0.253125], [0.09416666666666666, 0.253125]]}
# box = 1
#  rect_start = [113, 405]
#  width = 903
#  height = 1
#  opacity= 0.23247498618679374
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.175, 0.290625], [0.175, 0.253125], [0.8466666666666667, 0.253125], [0.8466666666666667, 0.253125], [0.825, 0.253125], [0.825, 0.290625], [0.09416666666666666, 0.290625], [0.09416666666666666, 0.290625]]}
# box = 3
#  rect_start = [131, 1133]
#  width = 903
#  height = 6
#  opacity= 0.4359158356821031
# num_subboxes = 6
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1575, 0.745625], [0.1575, 0.708125], [0.8616666666666667, 0.708125], [0.8616666666666667, 0.895625], [0.8541666666666666, 0.895625], [0.8541666666666666, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.745625]]}
#
#
# box = 0
#  rect_start = [112, 222]
#  width = 901
#  height = 1
#  opacity= 0.2146788521254835
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.16666666666666666, 0.17625], [0.16666666666666666, 0.13875], [0.8441666666666666, 0.13875], [0.8441666666666666, 0.13875], [0.7916666666666666, 0.13875], [0.7916666666666666, 0.17625], [0.09333333333333334, 0.17625], [0.09333333333333334, 0.17625]]}
# box = 2
#  rect_start = [115, 644]
#  width = 903
#  height = 3
#  opacity= 0.306822495309173
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.17583333333333334, 0.44], [0.17583333333333334, 0.4025], [0.8483333333333334, 0.4025], [0.8483333333333334, 0.4775], [0.7958333333333333, 0.4775], [0.7958333333333333, 0.515], [0.09583333333333334, 0.515], [0.09583333333333334, 0.44]]}
# box = 3
#  rect_start = [131, 1013]
#  width = 903
#  height = 7
#  opacity= 0.509070053070802
# num_subboxes = 7
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.12916666666666668, 0.670625], [0.12916666666666668, 0.633125], [0.8616666666666667, 0.633125], [0.8616666666666667, 0.858125], [0.7983333333333333, 0.858125], [0.7983333333333333, 0.895625], [0.10916666666666666, 0.895625], [0.10916666666666666, 0.670625]]}
# box = 3
#  rect_start = [131, 1433]
#  width = 903
#  height = 1
#  opacity= 0.4263712247663747
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.14833333333333334, 0.933125], [0.14833333333333334, 0.895625], [0.8616666666666667, 0.895625], [0.8616666666666667, 0.895625], [0.8158333333333333, 0.895625], [0.8158333333333333, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.933125]]}
#
#
# box = 0
#  rect_start = [112, 162]
#  width = 901
#  height = 2
#  opacity= 0.5595634126801283
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.16083333333333333, 0.13875], [0.16083333333333333, 0.10125], [0.8441666666666666, 0.10125], [0.8441666666666666, 0.13875], [0.8175, 0.13875], [0.8175, 0.17625], [0.09333333333333334, 0.17625], [0.09333333333333334, 0.13875]]}
# box = 2
#  rect_start = [115, 764]
#  width = 903
#  height = 1
#  opacity= 0.30979215207129107
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.15666666666666668, 0.515], [0.15666666666666668, 0.4775], [0.8483333333333334, 0.4775], [0.8483333333333334, 0.4775], [0.8175, 0.4775], [0.8175, 0.515], [0.09583333333333334, 0.515], [0.09583333333333334, 0.515]]}
#
#
# box = 0
#  rect_start = [112, 162]
#  width = 901
#  height = 2
#  opacity= 0.27025602817772265
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.17083333333333334, 0.13875], [0.17083333333333334, 0.10125], [0.8441666666666666, 0.10125], [0.8441666666666666, 0.13875], [0.8308333333333333, 0.13875], [0.8308333333333333, 0.17625], [0.09333333333333334, 0.17625], [0.09333333333333334, 0.13875]]}
# box = 2
#  rect_start = [115, 524]
#  width = 903
#  height = 4
#  opacity= 0.5289669204907097
# num_subboxes = 4
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.135, 0.365], [0.135, 0.3275], [0.8483333333333334, 0.3275], [0.8483333333333334, 0.44], [0.7766666666666666, 0.44], [0.7766666666666666, 0.4775], [0.09583333333333334, 0.4775], [0.09583333333333334, 0.365]]}
# box = 2
#  rect_start = [115, 764]
#  width = 903
#  height = 1
#  opacity= 0.5802220679405707
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.09916666666666667, 0.515], [0.09916666666666667, 0.4775], [0.8483333333333334, 0.4775], [0.8483333333333334, 0.4775], [0.775, 0.4775], [0.775, 0.515], [0.09583333333333334, 0.515], [0.09583333333333334, 0.515]]}
# box = 3
#  rect_start = [131, 953]
#  width = 903
#  height = 4
#  opacity= 0.29742755886560945
# num_subboxes = 4
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1775, 0.633125], [0.1775, 0.595625], [0.8616666666666667, 0.595625], [0.8616666666666667, 0.708125], [0.7941666666666667, 0.708125], [0.7941666666666667, 0.745625], [0.10916666666666666, 0.745625], [0.10916666666666666, 0.633125]]}
# box = 3
#  rect_start = [131, 1433]
#  width = 903
#  height = 1
#  opacity= 0.4573362736821955
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.17416666666666666, 0.933125], [0.17416666666666666, 0.895625], [0.8616666666666667, 0.895625], [0.8616666666666667, 0.895625], [0.8575, 0.895625], [0.8575, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.933125]]}
#
#
# box = 0
#  rect_start = [112, 162]
#  width = 901
#  height = 1
#  opacity= 0.4848611185705228
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.10666666666666667, 0.13875], [0.10666666666666667, 0.10125], [0.8441666666666666, 0.10125], [0.8441666666666666, 0.10125], [0.815, 0.10125], [0.815, 0.13875], [0.09333333333333334, 0.13875], [0.09333333333333334, 0.13875]]}
# box = 0
#  rect_start = [112, 222]
#  width = 901
#  height = 1
#  opacity= 0.49184500305380174
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1175, 0.17625], [0.1175, 0.13875], [0.8441666666666666, 0.13875], [0.8441666666666666, 0.13875], [0.8008333333333333, 0.13875], [0.8008333333333333, 0.17625], [0.09333333333333334, 0.17625], [0.09333333333333334, 0.17625]]}
# box = 3
#  rect_start = [131, 1373]
#  width = 903
#  height = 1
#  opacity= 0.3643234531688633
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.17166666666666666, 0.895625], [0.17166666666666666, 0.858125], [0.8616666666666667, 0.858125], [0.8616666666666667, 0.858125], [0.8025, 0.858125], [0.8025, 0.895625], [0.10916666666666666, 0.895625], [0.10916666666666666, 0.895625]]}
# box = 3
#  rect_start = [131, 1433]
#  width = 903
#  height = 1
#  opacity= 0.290463637731139
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.14583333333333334, 0.933125], [0.14583333333333334, 0.895625], [0.8616666666666667, 0.895625], [0.8616666666666667, 0.895625], [0.8025, 0.895625], [0.8025, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.933125]]}
#
#
# box = 1
#  rect_start = [113, 405]
#  width = 903
#  height = 1
#  opacity= 0.3603137375998062
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13083333333333333, 0.290625], [0.13083333333333333, 0.253125], [0.8466666666666667, 0.253125], [0.8466666666666667, 0.253125], [0.8466666666666667, 0.253125], [0.8466666666666667, 0.290625], [0.09416666666666666, 0.290625], [0.09416666666666666, 0.290625]]}
# box = 2
#  rect_start = [115, 644]
#  width = 903
#  height = 3
#  opacity= 0.26223196136179533
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13, 0.44], [0.13, 0.4025], [0.8483333333333334, 0.4025], [0.8483333333333334, 0.4775], [0.7658333333333334, 0.4775], [0.7658333333333334, 0.515], [0.09583333333333334, 0.515], [0.09583333333333334, 0.44]]}
# box = 3
#  rect_start = [131, 953]
#  width = 903
#  height = 1
#  opacity= 0.4130329391469695
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.16166666666666665, 0.633125], [0.16166666666666665, 0.595625], [0.8616666666666667, 0.595625], [0.8616666666666667, 0.595625], [0.7825, 0.595625], [0.7825, 0.633125], [0.10916666666666666, 0.633125], [0.10916666666666666, 0.633125]]}
#
#
# box = 2
#  rect_start = [115, 704]
#  width = 903
#  height = 2
#  opacity= 0.20834262360989952
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.17083333333333334, 0.4775], [0.17083333333333334, 0.44], [0.8483333333333334, 0.44], [0.8483333333333334, 0.4775], [0.7808333333333334, 0.4775], [0.7808333333333334, 0.515], [0.09583333333333334, 0.515], [0.09583333333333334, 0.4775]]}
# box = 3
#  rect_start = [131, 1193]
#  width = 903
#  height = 2
#  opacity= 0.27756148250676016
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.11666666666666667, 0.783125], [0.11666666666666667, 0.745625], [0.8616666666666667, 0.745625], [0.8616666666666667, 0.783125], [0.8075, 0.783125], [0.8075, 0.820625], [0.10916666666666666, 0.820625], [0.10916666666666666, 0.783125]]}
# box = 3
#  rect_start = [131, 1433]
#  width = 903
#  height = 1
#  opacity= 0.3768832255345139
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.17583333333333334, 0.933125], [0.17583333333333334, 0.895625], [0.8616666666666667, 0.895625], [0.8616666666666667, 0.895625], [0.8283333333333334, 0.895625], [0.8283333333333334, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.933125]]}
#
#
# box = 2
#  rect_start = [115, 524]
#  width = 903
#  height = 1
#  opacity= 0.42172654853532154
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.16083333333333333, 0.365], [0.16083333333333333, 0.3275], [0.8483333333333334, 0.3275], [0.8483333333333334, 0.3275], [0.785, 0.3275], [0.785, 0.365], [0.09583333333333334, 0.365], [0.09583333333333334, 0.365]]}
# box = 2
#  rect_start = [115, 584]
#  width = 903
#  height = 2
#  opacity= 0.4439221625290698
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1, 0.4025], [0.1, 0.365], [0.8483333333333334, 0.365], [0.8483333333333334, 0.4025], [0.8225, 0.4025], [0.8225, 0.44], [0.09583333333333334, 0.44], [0.09583333333333334, 0.4025]]}
# box = 2
#  rect_start = [115, 764]
#  width = 903
#  height = 1
#  opacity= 0.43309580583456786
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1725, 0.515], [0.1725, 0.4775], [0.8483333333333334, 0.4775], [0.8483333333333334, 0.4775], [0.7783333333333333, 0.4775], [0.7783333333333333, 0.515], [0.09583333333333334, 0.515], [0.09583333333333334, 0.515]]}
# box = 3
#  rect_start = [131, 953]
#  width = 903
#  height = 7
#  opacity= 0.5804677254384537
# num_subboxes = 7
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.16333333333333333, 0.633125], [0.16333333333333333, 0.595625], [0.8616666666666667, 0.595625], [0.8616666666666667, 0.820625], [0.8233333333333334, 0.820625], [0.8233333333333334, 0.858125], [0.10916666666666666, 0.858125], [0.10916666666666666, 0.633125]]}
# box = 3
#  rect_start = [131, 1373]
#  width = 903
#  height = 1
#  opacity= 0.20210047932224717
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13916666666666666, 0.895625], [0.13916666666666666, 0.858125], [0.8616666666666667, 0.858125], [0.8616666666666667, 0.858125], [0.8116666666666666, 0.858125], [0.8116666666666666, 0.895625], [0.10916666666666666, 0.895625], [0.10916666666666666, 0.895625]]}
# box = 3
#  rect_start = [131, 1433]
#  width = 903
#  height = 1
#  opacity= 0.5175596434557752
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.14083333333333334, 0.933125], [0.14083333333333334, 0.895625], [0.8616666666666667, 0.895625], [0.8616666666666667, 0.895625], [0.8491666666666666, 0.895625], [0.8491666666666666, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.933125]]}
#
#
# box = 0
#  rect_start = [112, 162]
#  width = 901
#  height = 2
#  opacity= 0.22707172916353843
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1125, 0.13875], [0.1125, 0.10125], [0.8441666666666666, 0.10125], [0.8441666666666666, 0.13875], [0.7733333333333333, 0.13875], [0.7733333333333333, 0.17625], [0.09333333333333334, 0.17625], [0.09333333333333334, 0.13875]]}
# box = 1
#  rect_start = [113, 345]
#  width = 903
#  height = 1
#  opacity= 0.3858491598988151
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.13166666666666665, 0.253125], [0.13166666666666665, 0.215625], [0.8466666666666667, 0.215625], [0.8466666666666667, 0.215625], [0.7891666666666667, 0.215625], [0.7891666666666667, 0.253125], [0.09416666666666666, 0.253125], [0.09416666666666666, 0.253125]]}
# box = 1
#  rect_start = [113, 405]
#  width = 903
#  height = 1
#  opacity= 0.30132550608104697
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1275, 0.290625], [0.1275, 0.253125], [0.8466666666666667, 0.253125], [0.8466666666666667, 0.253125], [0.8141666666666667, 0.253125], [0.8141666666666667, 0.290625], [0.09416666666666666, 0.290625], [0.09416666666666666, 0.290625]]}
# box = 2
#  rect_start = [115, 644]
#  width = 903
#  height = 1
#  opacity= 0.5204592349607096
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.14833333333333334, 0.44], [0.14833333333333334, 0.4025], [0.8483333333333334, 0.4025], [0.8483333333333334, 0.4025], [0.775, 0.4025], [0.775, 0.44], [0.09583333333333334, 0.44], [0.09583333333333334, 0.44]]}
# box = 3
#  rect_start = [131, 1133]
#  width = 903
#  height = 3
#  opacity= 0.3788518638681029
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.15666666666666668, 0.745625], [0.15666666666666668, 0.708125], [0.8616666666666667, 0.708125], [0.8616666666666667, 0.783125], [0.7975, 0.783125], [0.7975, 0.820625], [0.10916666666666666, 0.820625], [0.10916666666666666, 0.745625]]}
# box = 3
#  rect_start = [131, 1373]
#  width = 903
#  height = 2
#  opacity= 0.5795294117062226
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.16916666666666666, 0.895625], [0.16916666666666666, 0.858125], [0.8616666666666667, 0.858125], [0.8616666666666667, 0.895625], [0.8583333333333333, 0.895625], [0.8583333333333333, 0.933125], [0.10916666666666666, 0.933125], [0.10916666666666666, 0.895625]]}
#
#
# box = 0
#  rect_start = [128, 902]
#  width = 940
#  height = 3
#  opacity= 0.3808170740981589
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.18, 0.605625], [0.18, 0.56375], [0.89, 0.56375], [0.89, 0.6475], [0.8383333333333334, 0.6475], [0.8383333333333334, 0.689375], [0.10666666666666667, 0.689375], [0.10666666666666667, 0.605625]]}
#
#
# box = 0
#  rect_start = [128, 902]
#  width = 940
#  height = 3
#  opacity= 0.3237162870113849
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.15583333333333332, 0.605625], [0.15583333333333332, 0.56375], [0.89, 0.56375], [0.89, 0.6475], [0.8316666666666667, 0.6475], [0.8316666666666667, 0.689375], [0.10666666666666667, 0.689375], [0.10666666666666667, 0.605625]]}
# box = 0
#  rect_start = [128, 1170]
#  width = 940
#  height = 2
#  opacity= 0.25006811805076107
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.115, 0.773125], [0.115, 0.73125], [0.89, 0.73125], [0.89, 0.773125], [0.8633333333333333, 0.773125], [0.8633333333333333, 0.815], [0.10666666666666667, 0.815], [0.10666666666666667, 0.773125]]}
#
#
#
#
# box = 0
#  rect_start = [128, 969]
#  width = 940
#  height = 2
#  opacity= 0.3992152240544464
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.18833333333333332, 0.6475], [0.18833333333333332, 0.605625], [0.89, 0.605625], [0.89, 0.6475], [0.8291666666666667, 0.6475], [0.8291666666666667, 0.689375], [0.10666666666666667, 0.689375], [0.10666666666666667, 0.6475]]}
# box = 0
#  rect_start = [128, 1103]
#  width = 940
#  height = 2
#  opacity= 0.2523064606209546
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.17083333333333334, 0.73125], [0.17083333333333334, 0.689375], [0.89, 0.689375], [0.89, 0.73125], [0.875, 0.73125], [0.875, 0.773125], [0.10666666666666667, 0.773125], [0.10666666666666667, 0.73125]]}
# box = 0
#  rect_start = [128, 1237]
#  width = 940
#  height = 1
#  opacity= 0.3995038833590616
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.12666666666666668, 0.815], [0.12666666666666668, 0.773125], [0.89, 0.773125], [0.89, 0.773125], [0.8091666666666667, 0.773125], [0.8091666666666667, 0.815], [0.10666666666666667, 0.815], [0.10666666666666667, 0.815]]}
#
#
#
#
#
#
# box = 0
#  rect_start = [128, 902]
#  width = 940
#  height = 6
#  opacity= 0.37237110773901616
# num_subboxes = 6
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.17833333333333334, 0.605625], [0.17833333333333334, 0.56375], [0.89, 0.56375], [0.89, 0.773125], [0.84, 0.773125], [0.84, 0.815], [0.10666666666666667, 0.815], [0.10666666666666667, 0.605625]]}
#
#
#
#
# box = 0
#  rect_start = [128, 567]
#  width = 940
#  height = 11
#  opacity= 0.43105375834567317
# num_subboxes = 11
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.10916666666666666, 0.39625], [0.10916666666666666, 0.354375], [0.89, 0.354375], [0.89, 0.773125], [0.8266666666666667, 0.773125], [0.8266666666666667, 0.815], [0.10666666666666667, 0.815], [0.10666666666666667, 0.39625]]}
#
#
# box = 0
#  rect_start = [128, 500]
#  width = 940
#  height = 4
#  opacity= 0.4462708137657969
# num_subboxes = 4
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.16333333333333333, 0.354375], [0.16333333333333333, 0.3125], [0.89, 0.3125], [0.89, 0.438125], [0.8616666666666667, 0.438125], [0.8616666666666667, 0.48], [0.10666666666666667, 0.48], [0.10666666666666667, 0.354375]]}
# box = 0
#  rect_start = [128, 1237]
#  width = 940
#  height = 1
#  opacity= 0.3322736387327142
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.12083333333333333, 0.815], [0.12083333333333333, 0.773125], [0.89, 0.773125], [0.89, 0.773125], [0.8366666666666667, 0.773125], [0.8366666666666667, 0.815], [0.10666666666666667, 0.815], [0.10666666666666667, 0.815]]}
#
#
# box = 0
#  rect_start = [128, 969]
#  width = 940
#  height = 2
#  opacity= 0.3311706634960704
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.125, 0.6475], [0.125, 0.605625], [0.89, 0.605625], [0.89, 0.6475], [0.825, 0.6475], [0.825, 0.689375], [0.10666666666666667, 0.689375], [0.10666666666666667, 0.6475]]}
# box = 0
#  rect_start = [128, 1237]
#  width = 940
#  height = 1
#  opacity= 0.3621666451873589
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1125, 0.815], [0.1125, 0.773125], [0.89, 0.773125], [0.89, 0.773125], [0.8191666666666667, 0.773125], [0.8191666666666667, 0.815], [0.10666666666666667, 0.815], [0.10666666666666667, 0.815]]}
#
#
# box = 0
#  rect_start = [128, 768]
#  width = 940
#  height = 6
#  opacity= 0.5302414036345828
# num_subboxes = 6
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.15083333333333335, 0.521875], [0.15083333333333335, 0.48], [0.89, 0.48], [0.89, 0.689375], [0.8158333333333333, 0.689375], [0.8158333333333333, 0.73125], [0.10666666666666667, 0.73125], [0.10666666666666667, 0.521875]]}
#
#
# box = 0
#  rect_start = [128, 701]
#  width = 940
#  height = 9
#  opacity= 0.385201560477912
# num_subboxes = 9
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.12, 0.48], [0.12, 0.438125], [0.89, 0.438125], [0.89, 0.773125], [0.8125, 0.773125], [0.8125, 0.815], [0.10666666666666667, 0.815], [0.10666666666666667, 0.48]]}
#
#
# box = 0
#  rect_start = [128, 1103]
#  width = 940
#  height = 3
#  opacity= 0.5658964695263622
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.15666666666666668, 0.73125], [0.15666666666666668, 0.689375], [0.89, 0.689375], [0.89, 0.773125], [0.865, 0.773125], [0.865, 0.815], [0.10666666666666667, 0.815], [0.10666666666666667, 0.73125]]}
#
#
# box = 0
#  rect_start = [128, 768]
#  width = 940
#  height = 4
#  opacity= 0.4987516909824967
# num_subboxes = 4
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.14166666666666666, 0.521875], [0.14166666666666666, 0.48], [0.89, 0.48], [0.89, 0.605625], [0.8583333333333333, 0.605625], [0.8583333333333333, 0.6475], [0.10666666666666667, 0.6475], [0.10666666666666667, 0.521875]]}
# box = 0
#  rect_start = [128, 1103]
#  width = 940
#  height = 3
#  opacity= 0.5667597558777466
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.14416666666666667, 0.73125], [0.14416666666666667, 0.689375], [0.89, 0.689375], [0.89, 0.773125], [0.8725, 0.773125], [0.8725, 0.815], [0.10666666666666667, 0.815], [0.10666666666666667, 0.73125]]}
#
#
# box = 0
#  rect_start = [56, 153]
#  width = 466
#  height = 1
#  opacity= 0.5672195377836045
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.04833333333333333, 0.11375], [0.04833333333333333, 0.095625], [0.435, 0.095625], [0.435, 0.095625], [0.38166666666666665, 0.095625], [0.38166666666666665, 0.11375], [0.04666666666666667, 0.11375], [0.04666666666666667, 0.11375]]}
# box = 1
#  rect_start = [56, 298]
#  width = 494
#  height = 2
#  opacity= 0.46149428782366125
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.10666666666666667, 0.204375], [0.10666666666666667, 0.18625], [0.4583333333333333, 0.18625], [0.4583333333333333, 0.204375], [0.4325, 0.204375], [0.4325, 0.2225], [0.04666666666666667, 0.2225], [0.04666666666666667, 0.204375]]}
# box = 4
#  rect_start = [56, 1184]
#  width = 483
#  height = 1
#  opacity= 0.42540394561919337
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.075, 0.758125], [0.075, 0.74], [0.44916666666666666, 0.74], [0.44916666666666666, 0.74], [0.445, 0.74], [0.445, 0.758125], [0.04666666666666667, 0.758125], [0.04666666666666667, 0.758125]]}
# box = 5
#  rect_start = [56, 1379]
#  width = 504
#  height = 5
#  opacity= 0.5161992340936599
# num_subboxes = 5
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.0875, 0.88], [0.0875, 0.861875], [0.4666666666666667, 0.861875], [0.4666666666666667, 0.934375], [0.395, 0.934375], [0.395, 0.9525], [0.04666666666666667, 0.9525], [0.04666666666666667, 0.88]]}
# box = 7
#  rect_start = [594, 1086]
#  width = 499
#  height = 3
#  opacity= 0.4899375376139165
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5358333333333334, 0.696875], [0.5358333333333334, 0.67875], [0.9108333333333334, 0.67875], [0.9108333333333334, 0.715], [0.91, 0.715], [0.91, 0.733125], [0.495, 0.733125], [0.495, 0.696875]]}
# box = 7
#  rect_start = [594, 1173]
#  width = 499
#  height = 1
#  opacity= 0.5261901880012012
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5608333333333333, 0.75125], [0.5608333333333333, 0.733125], [0.9108333333333334, 0.733125], [0.9108333333333334, 0.733125], [0.8708333333333333, 0.733125], [0.8708333333333333, 0.75125], [0.495, 0.75125], [0.495, 0.75125]]}
# box = 8
#  rect_start = [594, 1491]
#  width = 499
#  height = 2
#  opacity= 0.5265978061731652
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5558333333333333, 0.95], [0.5558333333333333, 0.931875], [0.9108333333333334, 0.931875], [0.9108333333333334, 0.95], [0.8275, 0.95], [0.8275, 0.968125], [0.495, 0.968125], [0.495, 0.95]]}
#
#
# box = 0
#  rect_start = [56, 124]
#  width = 466
#  height = 1
#  opacity= 0.48609455651977046
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.11416666666666667, 0.095625], [0.11416666666666667, 0.0775], [0.435, 0.0775], [0.435, 0.0775], [0.4033333333333333, 0.0775], [0.4033333333333333, 0.095625], [0.04666666666666667, 0.095625], [0.04666666666666667, 0.095625]]}
# box = 0
#  rect_start = [56, 153]
#  width = 466
#  height = 1
#  opacity= 0.24374777009771478
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.085, 0.11375], [0.085, 0.095625], [0.435, 0.095625], [0.435, 0.095625], [0.36083333333333334, 0.095625], [0.36083333333333334, 0.11375], [0.04666666666666667, 0.11375], [0.04666666666666667, 0.11375]]}
# box = 1
#  rect_start = [56, 327]
#  width = 494
#  height = 1
#  opacity= 0.4761749222888523
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.09416666666666666, 0.2225], [0.09416666666666666, 0.204375], [0.4583333333333333, 0.204375], [0.4583333333333333, 0.204375], [0.4191666666666667, 0.204375], [0.4191666666666667, 0.2225], [0.04666666666666667, 0.2225], [0.04666666666666667, 0.2225]]}
# box = 2
#  rect_start = [77, 545]
#  width = 469
#  height = 3
#  opacity= 0.3904650124836654
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.1125, 0.3625], [0.1125, 0.340625], [0.455, 0.340625], [0.455, 0.384375], [0.37166666666666665, 0.384375], [0.37166666666666665, 0.40625], [0.06416666666666666, 0.40625], [0.06416666666666666, 0.3625]]}
# box = 2
#  rect_start = [77, 650]
#  width = 469
#  height = 2
#  opacity= 0.3718211364413374
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.10583333333333333, 0.428125], [0.10583333333333333, 0.40625], [0.455, 0.40625], [0.455, 0.428125], [0.4525, 0.428125], [0.4525, 0.45], [0.06416666666666666, 0.45], [0.06416666666666666, 0.428125]]}
# box = 3
#  rect_start = [56, 953]
#  width = 483
#  height = 3
#  opacity= 0.4688440326867931
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.065, 0.61375], [0.065, 0.595625], [0.44916666666666666, 0.595625], [0.44916666666666666, 0.631875], [0.3775, 0.631875], [0.3775, 0.65], [0.04666666666666667, 0.65], [0.04666666666666667, 0.61375]]}
# box = 4
#  rect_start = [56, 1155]
#  width = 483
#  height = 2
#  opacity= 0.2669013949712235
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.09, 0.74], [0.09, 0.721875], [0.44916666666666666, 0.721875], [0.44916666666666666, 0.74], [0.37666666666666665, 0.74], [0.37666666666666665, 0.758125], [0.04666666666666667, 0.758125], [0.04666666666666667, 0.74]]}
# box = 7
#  rect_start = [594, 1144]
#  width = 499
#  height = 1
#  opacity= 0.24096657555099932
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5758333333333333, 0.733125], [0.5758333333333333, 0.715], [0.9108333333333334, 0.715], [0.9108333333333334, 0.715], [0.8341666666666666, 0.715], [0.8341666666666666, 0.733125], [0.495, 0.733125], [0.495, 0.733125]]}
#
#
# box = 0
#  rect_start = [56, 153]
#  width = 466
#  height = 1
#  opacity= 0.25569398637071045
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.12166666666666667, 0.11375], [0.12166666666666667, 0.095625], [0.435, 0.095625], [0.435, 0.095625], [0.37, 0.095625], [0.37, 0.11375], [0.04666666666666667, 0.11375], [0.04666666666666667, 0.11375]]}
# box = 1
#  rect_start = [56, 269]
#  width = 494
#  height = 3
#  opacity= 0.5675074847319301
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.075, 0.18625], [0.075, 0.168125], [0.4583333333333333, 0.168125], [0.4583333333333333, 0.204375], [0.4041666666666667, 0.204375], [0.4041666666666667, 0.2225], [0.04666666666666667, 0.2225], [0.04666666666666667, 0.18625]]}
# box = 2
#  rect_start = [77, 580]
#  width = 469
#  height = 1
#  opacity= 0.307414735325769
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.12083333333333333, 0.384375], [0.12083333333333333, 0.3625], [0.455, 0.3625], [0.455, 0.3625], [0.41333333333333333, 0.3625], [0.41333333333333333, 0.384375], [0.06416666666666666, 0.384375], [0.06416666666666666, 0.384375]]}
# box = 4
#  rect_start = [56, 1068]
#  width = 483
#  height = 1
#  opacity= 0.5982776274937149
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.06333333333333334, 0.685625], [0.06333333333333334, 0.6675], [0.44916666666666666, 0.6675], [0.44916666666666666, 0.6675], [0.4025, 0.6675], [0.4025, 0.685625], [0.04666666666666667, 0.685625], [0.04666666666666667, 0.685625]]}
# box = 4
#  rect_start = [56, 1155]
#  width = 483
#  height = 1
#  opacity= 0.45024170966598165
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.08583333333333333, 0.74], [0.08583333333333333, 0.721875], [0.44916666666666666, 0.721875], [0.44916666666666666, 0.721875], [0.37833333333333335, 0.721875], [0.37833333333333335, 0.74], [0.04666666666666667, 0.74], [0.04666666666666667, 0.74]]}
# box = 4
#  rect_start = [56, 1184]
#  width = 483
#  height = 1
#  opacity= 0.5268436107653194
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.10166666666666667, 0.758125], [0.10166666666666667, 0.74], [0.44916666666666666, 0.74], [0.44916666666666666, 0.74], [0.37666666666666665, 0.74], [0.37666666666666665, 0.758125], [0.04666666666666667, 0.758125], [0.04666666666666667, 0.758125]]}
# box = 6
#  rect_start = [594, 919]
#  width = 499
#  height = 2
#  opacity= 0.22736464300903161
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.535, 0.5925], [0.535, 0.574375], [0.9108333333333334, 0.574375], [0.9108333333333334, 0.5925], [0.8283333333333334, 0.5925], [0.8283333333333334, 0.610625], [0.495, 0.610625], [0.495, 0.5925]]}
# box = 6
#  rect_start = [594, 1035]
#  width = 499
#  height = 1
#  opacity= 0.45784822727515906
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5316666666666666, 0.665], [0.5316666666666666, 0.646875], [0.9108333333333334, 0.646875], [0.9108333333333334, 0.646875], [0.8658333333333333, 0.646875], [0.8658333333333333, 0.665], [0.495, 0.665], [0.495, 0.665]]}
# box = 7
#  rect_start = [594, 1115]
#  width = 499
#  height = 3
#  opacity= 0.3543542299054374
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5366666666666666, 0.715], [0.5366666666666666, 0.696875], [0.9108333333333334, 0.696875], [0.9108333333333334, 0.733125], [0.88, 0.733125], [0.88, 0.75125], [0.495, 0.75125], [0.495, 0.715]]}
# box = 8
#  rect_start = [594, 1491]
#  width = 499
#  height = 2
#  opacity= 0.31098709429382404
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5033333333333333, 0.95], [0.5033333333333333, 0.931875], [0.9108333333333334, 0.931875], [0.9108333333333334, 0.95], [0.8433333333333334, 0.95], [0.8433333333333334, 0.968125], [0.495, 0.968125], [0.495, 0.95]]}
#
#
# box = 3
#  rect_start = [56, 924]
#  width = 483
#  height = 3
#  opacity= 0.3340044105264778
# num_subboxes = 3
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.06416666666666666, 0.595625], [0.06416666666666666, 0.5775], [0.44916666666666666, 0.5775], [0.44916666666666666, 0.61375], [0.41, 0.61375], [0.41, 0.631875], [0.04666666666666667, 0.631875], [0.04666666666666667, 0.595625]]}
# box = 3
#  rect_start = [56, 1011]
#  width = 483
#  height = 1
#  opacity= 0.3677477217451194
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.0875, 0.65], [0.0875, 0.631875], [0.44916666666666666, 0.631875], [0.44916666666666666, 0.631875], [0.43333333333333335, 0.631875], [0.43333333333333335, 0.65], [0.04666666666666667, 0.65], [0.04666666666666667, 0.65]]}
# box = 5
#  rect_start = [56, 1292]
#  width = 504
#  height = 7
#  opacity= 0.421236558129627
# num_subboxes = 7
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.05333333333333334, 0.825625], [0.05333333333333334, 0.8075], [0.4666666666666667, 0.8075], [0.4666666666666667, 0.91625], [0.4175, 0.91625], [0.4175, 0.934375], [0.04666666666666667, 0.934375], [0.04666666666666667, 0.825625]]}
# box = 5
#  rect_start = [56, 1495]
#  width = 504
#  height = 1
#  opacity= 0.38076683076711804
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.08, 0.9525], [0.08, 0.934375], [0.4666666666666667, 0.934375], [0.4666666666666667, 0.934375], [0.42333333333333334, 0.934375], [0.42333333333333334, 0.9525], [0.04666666666666667, 0.9525], [0.04666666666666667, 0.9525]]}
# box = 7
#  rect_start = [594, 1173]
#  width = 499
#  height = 1
#  opacity= 0.5418405218488012
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5666666666666667, 0.75125], [0.5666666666666667, 0.733125], [0.9108333333333334, 0.733125], [0.9108333333333334, 0.733125], [0.8791666666666667, 0.733125], [0.8791666666666667, 0.75125], [0.495, 0.75125], [0.495, 0.75125]]}
# box = 8
#  rect_start = [594, 1462]
#  width = 499
#  height = 2
#  opacity= 0.43444750088101813
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5341666666666667, 0.931875], [0.5341666666666667, 0.91375], [0.9108333333333334, 0.91375], [0.9108333333333334, 0.931875], [0.8383333333333334, 0.931875], [0.8383333333333334, 0.95], [0.495, 0.95], [0.495, 0.931875]]}
# box = 8
#  rect_start = [594, 1520]
#  width = 499
#  height = 1
#  opacity= 0.5533695195574504
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.5325, 0.968125], [0.5325, 0.95], [0.9108333333333334, 0.95], [0.9108333333333334, 0.95], [0.8883333333333333, 0.95], [0.8883333333333333, 0.968125], [0.495, 0.968125], [0.495, 0.968125]]}
#
#
# box = 1
#  rect_start = [56, 298]
#  width = 494
#  height = 1
#  opacity= 0.5976349109475854
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.09083333333333334, 0.204375], [0.09083333333333334, 0.18625], [0.4583333333333333, 0.18625], [0.4583333333333333, 0.18625], [0.4375, 0.18625], [0.4375, 0.204375], [0.04666666666666667, 0.204375], [0.04666666666666667, 0.204375]]}
# box = 1
#  rect_start = [56, 327]
#  width = 494
#  height = 1
#  opacity= 0.2117213842146539
# num_subboxes = 1
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.075, 0.2225], [0.075, 0.204375], [0.4583333333333333, 0.204375], [0.4583333333333333, 0.204375], [0.43916666666666665, 0.204375], [0.43916666666666665, 0.2225], [0.04666666666666667, 0.2225], [0.04666666666666667, 0.2225]]}
# box = 3
#  rect_start = [56, 953]
#  width = 483
#  height = 2
#  opacity= 0.5655920016514138
# num_subboxes = 2
# img_width = 1200, img_height = 1600
# {'class': 0, 'poly': [[0.065, 0.61375], [0.065, 0.595625], [0.44916666666666666, 0.595625], [0.44916666666666666, 0.61375], [0.43083333333333335, 0.61375], [0.43083333333333335, 0.631875], [0.04666666666666667, 0.631875], [0.04666666666666667, 0.61375]]}
# box = 4
#  rect_start = [56, 1068]
#  width = 483
#  height = 3
#  opacity= 0.22382238513801364
# num_subboxes = 3
# ...
# box = 2
#  rect_start = [21, 737]
#  width = 614
#  height = 1
#  opacity= 0.3377890698631186
# num_subboxes = 1
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.17185185185185184, 0.6711111111111111], [0.17185185185185184, 0.6551111111111111], [0.9407407407407408, 0.6551111111111111], [0.9407407407407408, 0.6551111111111111], [0.8311111111111111, 0.6551111111111111], [0.8311111111111111, 0.6711111111111111], [0.03111111111111111, 0.6711111111111111], [0.03111111111111111, 0.6711111111111111]]}
#
#
# box = 0
#  rect_start = [21, 175]
#  width = 614
#  height = 2
#  opacity= 0.48744211283961425
# num_subboxes = 2
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.15703703703703703, 0.168], [0.15703703703703703, 0.15555555555555556], [0.9407407407407408, 0.15555555555555556], [0.9407407407407408, 0.168], [0.92, 0.168], [0.92, 0.18044444444444444], [0.03111111111111111, 0.18044444444444444], [0.03111111111111111, 0.168]]}
# box = 0
#  rect_start = [21, 259]
#  width = 614
#  height = 1
#  opacity= 0.49255264277786365
# num_subboxes = 1
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.05185185185185185, 0.24266666666666667], [0.05185185185185185, 0.23022222222222222], [0.9407407407407408, 0.23022222222222222], [0.9407407407407408, 0.23022222222222222], [0.8651851851851852, 0.23022222222222222], [0.8651851851851852, 0.24266666666666667], [0.03111111111111111, 0.24266666666666667], [0.03111111111111111, 0.24266666666666667]]}
# box = 0
#  rect_start = [21, 273]
#  width = 614
#  height = 1
#  opacity= 0.5178263637435163
# num_subboxes = 1
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.12148148148148148, 0.2551111111111111], [0.12148148148148148, 0.24266666666666667], [0.9407407407407408, 0.24266666666666667], [0.9407407407407408, 0.24266666666666667], [0.8162962962962963, 0.24266666666666667], [0.8162962962962963, 0.2551111111111111], [0.03111111111111111, 0.2551111111111111], [0.03111111111111111, 0.2551111111111111]]}
# box = 1
#  rect_start = [21, 393]
#  width = 614
#  height = 1
#  opacity= 0.36018267873055315
# num_subboxes = 1
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.037037037037037035, 0.36444444444444446], [0.037037037037037035, 0.34933333333333333], [0.9407407407407408, 0.34933333333333333], [0.9407407407407408, 0.34933333333333333], [0.9274074074074075, 0.34933333333333333], [0.9274074074074075, 0.36444444444444446], [0.03111111111111111, 0.36444444444444446], [0.03111111111111111, 0.36444444444444446]]}
# box = 1
#  rect_start = [21, 410]
#  width = 614
#  height = 1
#  opacity= 0.44088869404660314
# num_subboxes = 1
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.05333333333333334, 0.37955555555555553], [0.05333333333333334, 0.36444444444444446], [0.9407407407407408, 0.36444444444444446], [0.9407407407407408, 0.36444444444444446], [0.8651851851851852, 0.36444444444444446], [0.8651851851851852, 0.37955555555555553], [0.03111111111111111, 0.37955555555555553], [0.03111111111111111, 0.37955555555555553]]}
# box = 2
#  rect_start = [21, 503]
#  width = 614
#  height = 4
#  opacity= 0.4261897086631353
# num_subboxes = 4
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.09037037037037036, 0.4631111111111111], [0.09037037037037036, 0.4471111111111111], [0.9407407407407408, 0.4471111111111111], [0.9407407407407408, 0.4951111111111111], [0.9037037037037037, 0.4951111111111111], [0.9037037037037037, 0.5111111111111111], [0.03111111111111111, 0.5111111111111111], [0.03111111111111111, 0.4631111111111111]]}
# box = 2
#  rect_start = [21, 629]
#  width = 614
#  height = 4
#  opacity= 0.5440745187661149
# num_subboxes = 4
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.12, 0.5751111111111111], [0.12, 0.5591111111111111], [0.9407407407407408, 0.5591111111111111], [0.9407407407407408, 0.6071111111111112], [0.8444444444444444, 0.6071111111111112], [0.8444444444444444, 0.6231111111111111], [0.03111111111111111, 0.6231111111111111], [0.03111111111111111, 0.5751111111111111]]}
# box = 2
#  rect_start = [21, 719]
#  width = 614
#  height = 2
#  opacity= 0.5573684754224175
# num_subboxes = 2
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.06222222222222222, 0.6551111111111111], [0.06222222222222222, 0.6391111111111111], [0.9407407407407408, 0.6391111111111111], [0.9407407407407408, 0.6551111111111111], [0.88, 0.6551111111111111], [0.88, 0.6711111111111111], [0.03111111111111111, 0.6711111111111111], [0.03111111111111111, 0.6551111111111111]]}
# box = 3
#  rect_start = [21, 993]
#  width = 614
#  height = 1
#  opacity= 0.4803024760796694
# num_subboxes = 1
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.04148148148148148, 0.9057777777777778], [0.04148148148148148, 0.8826666666666667], [0.9407407407407408, 0.8826666666666667], [0.9407407407407408, 0.8826666666666667], [0.9362962962962963, 0.8826666666666667], [0.9362962962962963, 0.9057777777777778], [0.03111111111111111, 0.9057777777777778], [0.03111111111111111, 0.9057777777777778]]}
#
#
# box = 0
#  rect_start = [21, 133]
#  width = 614
#  height = 8
#  opacity= 0.3616829339661271
# num_subboxes = 8
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.1511111111111111, 0.13066666666666665], [0.1511111111111111, 0.11822222222222223], [0.9407407407407408, 0.11822222222222223], [0.9407407407407408, 0.20533333333333334], [0.8044444444444444, 0.20533333333333334], [0.8044444444444444, 0.21777777777777776], [0.03111111111111111, 0.21777777777777776], [0.03111111111111111, 0.13066666666666665]]}
# box = 0
#  rect_start = [21, 273]
#  width = 614
#  height = 1
#  opacity= 0.4668055356434025
# num_subboxes = 1
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.07407407407407407, 0.2551111111111111], [0.07407407407407407, 0.24266666666666667], [0.9407407407407408, 0.24266666666666667], [0.9407407407407408, 0.24266666666666667], [0.8711111111111111, 0.24266666666666667], [0.8711111111111111, 0.2551111111111111], [0.03111111111111111, 0.2551111111111111], [0.03111111111111111, 0.2551111111111111]]}
# box = 2
#  rect_start = [21, 647]
#  width = 614
#  height = 1
#  opacity= 0.25105030216763685
# num_subboxes = 1
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.1437037037037037, 0.5911111111111111], [0.1437037037037037, 0.5751111111111111], [0.9407407407407408, 0.5751111111111111], [0.9407407407407408, 0.5751111111111111], [0.797037037037037, 0.5751111111111111], [0.797037037037037, 0.5911111111111111], [0.03111111111111111, 0.5911111111111111], [0.03111111111111111, 0.5911111111111111]]}
# box = 2
#  rect_start = [21, 683]
#  width = 614
#  height = 3
#  opacity= 0.5719339658492401
# num_subboxes = 3
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.044444444444444446, 0.6231111111111111], [0.044444444444444446, 0.6071111111111112], [0.9407407407407408, 0.6071111111111112], [0.9407407407407408, 0.6391111111111111], [0.8251851851851851, 0.6391111111111111], [0.8251851851851851, 0.6551111111111111], [0.03111111111111111, 0.6551111111111111], [0.03111111111111111, 0.6231111111111111]]}
# box = 2
#  rect_start = [21, 737]
#  width = 614
#  height = 1
#  opacity= 0.4901541379240183
# num_subboxes = 1
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.15703703703703703, 0.6711111111111111], [0.15703703703703703, 0.6551111111111111], [0.9407407407407408, 0.6551111111111111], [0.9407407407407408, 0.6551111111111111], [0.914074074074074, 0.6551111111111111], [0.914074074074074, 0.6711111111111111], [0.03111111111111111, 0.6711111111111111], [0.03111111111111111, 0.6711111111111111]]}
# box = 3
#  rect_start = [21, 941]
#  width = 614
#  height = 2
#  opacity= 0.41789250302183767
# num_subboxes = 2
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.17925925925925926, 0.8595555555555555], [0.17925925925925926, 0.8364444444444444], [0.9407407407407408, 0.8364444444444444], [0.9407407407407408, 0.8595555555555555], [0.8711111111111111, 0.8595555555555555], [0.8711111111111111, 0.8826666666666667], [0.03111111111111111, 0.8826666666666667], [0.03111111111111111, 0.8595555555555555]]}
# box = 3
#  rect_start = [21, 993]
#  width = 614
#  height = 1
#  opacity= 0.5574719579316118
# num_subboxes = 1
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.07555555555555556, 0.9057777777777778], [0.07555555555555556, 0.8826666666666667], [0.9407407407407408, 0.8826666666666667], [0.9407407407407408, 0.8826666666666667], [0.8977777777777778, 0.8826666666666667], [0.8977777777777778, 0.9057777777777778], [0.03111111111111111, 0.9057777777777778], [0.03111111111111111, 0.9057777777777778]]}
#
#
# box = 1
#  rect_start = [21, 410]
#  width = 614
#  height = 1
#  opacity= 0.31214115379587193
# num_subboxes = 1
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.056296296296296296, 0.37955555555555553], [0.056296296296296296, 0.36444444444444446], [0.9407407407407408, 0.36444444444444446], [0.9407407407407408, 0.36444444444444446], [0.8740740740740741, 0.36444444444444446], [0.8740740740740741, 0.37955555555555553], [0.03111111111111111, 0.37955555555555553], [0.03111111111111111, 0.37955555555555553]]}
# box = 2
#  rect_start = [21, 575]
#  width = 614
#  height = 8
#  opacity= 0.3127936770776275
# num_subboxes = 8
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.17777777777777778, 0.5271111111111111], [0.17777777777777778, 0.5111111111111111], [0.9407407407407408, 0.5111111111111111], [0.9407407407407408, 0.6231111111111111], [0.8474074074074074, 0.6231111111111111], [0.8474074074074074, 0.6391111111111111], [0.03111111111111111, 0.6391111111111111], [0.03111111111111111, 0.5271111111111111]]}
# box = 2
#  rect_start = [21, 719]
#  width = 614
#  height = 1
#  opacity= 0.5710444741520244
# num_subboxes = 1
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.035555555555555556, 0.6551111111111111], [0.035555555555555556, 0.6391111111111111], [0.9407407407407408, 0.6391111111111111], [0.9407407407407408, 0.6391111111111111], [0.8844444444444445, 0.6391111111111111], [0.8844444444444445, 0.6551111111111111], [0.03111111111111111, 0.6551111111111111], [0.03111111111111111, 0.6551111111111111]]}
# box = 2
#  rect_start = [21, 737]
#  width = 614
#  height = 1
#  opacity= 0.24844399940669992
# num_subboxes = 1
# img_width = 675, img_height = 1125
# {'class': 0, 'poly': [[0.10518518518518519, 0.6711111111111111], [0.10518518518518519, 0.6551111111111111], [0.9407407407407408, 0.6551111111111111], [0.9407407407407408, 0.6551111111111111], [0.8992592592592593, 0.6551111111111111], [0.8992592592592593, 0.6711111111111111], [0.03111111111111111, 0.6711111111111111], [0.03111111111111111, 0.6711111111111111]]}
#
#
#
#
#
#
# box = 0
#  rect_start = [75, 561]
#  width = 459
#  height = 11
#  opacity= 0.44167812909845583
# num_subboxes = 11
# img_width = 630, img_height = 883
# {'class': 0, 'poly': [[0.16825396825396827, 0.6534541336353341], [0.16825396825396827, 0.6353340883352209], [0.8476190476190476, 0.6353340883352209], [0.8476190476190476, 0.8165345413363534], [0.8047619047619048, 0.8165345413363534], [0.8047619047619048, 0.8346545866364666], [0.11904761904761904, 0.8346545866364666], [0.11904761904761904, 0.6534541336353341]]}
#
#
# box = 0
#  rect_start = [75, 545]
#  width = 459
#  height = 4
#  opacity= 0.26212494394663666
# num_subboxes = 4
# img_width = 630, img_height = 883
# {'class': 0, 'poly': [[0.2571428571428571, 0.6353340883352209], [0.2571428571428571, 0.6172140430351076], [0.8476190476190476, 0.6172140430351076], [0.8476190476190476, 0.6715741789354474], [0.7492063492063492, 0.6715741789354474], [0.7492063492063492, 0.6896942242355606], [0.11904761904761904, 0.6896942242355606], [0.11904761904761904, 0.6353340883352209]]}
#
#
# box = 0
#  rect_start = [75, 561]
#  width = 459
#  height = 11
#  opacity= 0.5582067108461537
# num_subboxes = 11
# img_width = 630, img_height = 883
# {'class': 0, 'poly': [[0.21904761904761905, 0.6534541336353341], [0.21904761904761905, 0.6353340883352209], [0.8476190476190476, 0.6353340883352209], [0.8476190476190476, 0.8165345413363534], [0.765079365079365, 0.8165345413363534], [0.765079365079365, 0.8346545866364666], [0.11904761904761904, 0.8346545866364666], [0.11904761904761904, 0.6534541336353341]]}
#
#
#
#
# box = 0
#  rect_start = [75, 689]
#  width = 459
#  height = 3
#  opacity= 0.44438565233260324
# num_subboxes = 3
# img_width = 630, img_height = 883
# {'class': 0, 'poly': [[0.12857142857142856, 0.79841449603624], [0.12857142857142856, 0.7802944507361268], [0.8476190476190476, 0.7802944507361268], [0.8476190476190476, 0.8165345413363534], [0.7555555555555555, 0.8165345413363534], [0.7555555555555555, 0.8346545866364666], [0.11904761904761904, 0.8346545866364666], [0.11904761904761904, 0.79841449603624]]}
#
#
#
#
#
#
# box = 0
#  rect_start = [75, 641]
#  width = 459
#  height = 3
#  opacity= 0.5971405021927895
# num_subboxes = 3
# img_width = 630, img_height = 883
# {'class': 0, 'poly': [[0.14444444444444443, 0.7440543601359003], [0.14444444444444443, 0.7259343148357871], [0.8476190476190476, 0.7259343148357871], [0.8476190476190476, 0.7621744054360136], [0.7698412698412699, 0.7621744054360136], [0.7698412698412699, 0.7802944507361268], [0.11904761904761904, 0.7802944507361268], [0.11904761904761904, 0.7440543601359003]]}
# box = 0
#  rect_start = [75, 721]
#  width = 459
#  height = 1
#  opacity= 0.5299480666312094
# num_subboxes = 1
# img_width = 630, img_height = 883
# {'class': 0, 'poly': [[0.273015873015873, 0.8346545866364666], [0.273015873015873, 0.8165345413363534], [0.8476190476190476, 0.8165345413363534], [0.8476190476190476, 0.8165345413363534], [0.8301587301587302, 0.8165345413363534], [0.8301587301587302, 0.8346545866364666], [0.11904761904761904, 0.8346545866364666], [0.11904761904761904, 0.8346545866364666]]}
#
#
#
#
#
#
# box = 0
#  rect_start = [75, 689]
#  width = 459
#  height = 3
#  opacity= 0.22725508827343918
# num_subboxes = 3
# img_width = 630, img_height = 883
# {'class': 0, 'poly': [[0.23492063492063492, 0.79841449603624], [0.23492063492063492, 0.7802944507361268], [0.8476190476190476, 0.7802944507361268], [0.8476190476190476, 0.8165345413363534], [0.719047619047619, 0.8165345413363534], [0.719047619047619, 0.8346545866364666], [0.11904761904761904, 0.8346545866364666], [0.11904761904761904, 0.79841449603624]]}
#
#
#
#
# box = 0
#  rect_start = [75, 641]
#  width = 459
#  height = 3
#  opacity= 0.5161239293572222
# num_subboxes = 3
# img_width = 630, img_height = 883
# {'class': 0, 'poly': [[0.1253968253968254, 0.7440543601359003], [0.1253968253968254, 0.7259343148357871], [0.8476190476190476, 0.7259343148357871], [0.8476190476190476, 0.7621744054360136], [0.8301587301587302, 0.7621744054360136], [0.8301587301587302, 0.7802944507361268], [0.11904761904761904, 0.7802944507361268], [0.11904761904761904, 0.7440543601359003]]}
#
#
# box = 1
#  rect_start = [52, 440]
#  width = 221
#  height = 6
#  opacity= 0.4352249811523482
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 79
#      77 print(f"box = {box_num} \n rect_start = {variation_rect_start}\n width = {width} \n height = {highlight_height} \n opacity= {opacity}")
#      78 # Draw the adjusted rectangle
# ---> 79 intermediate_img, bbox_metadata = draw_broken_box_with_subboxes(
#      80     intermediate_img, variation_rect_start, width, highlight_height, thickness, delta, l1, l2, max_offset, color, opacity
#      81 )
#      83 # create line to be appended to the image label file
#      84 line_to_be_appended = f"{bbox_metadata['class']} "
#
# Cell In[5], line 24, in draw_broken_box_with_subboxes(background, rect_start, width, height_in_lines, thickness, delta, l1, l2, max_offset, color, opacity)
#      21 height_in_pixels = height_in_lines*thickness
#      23 # Create an overlay image (same size as the background)
# ---> 24 overlay = background.copy()
#      26 # Define the top-left starting point of the rectangle
#      27 x, y = rect_start
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %%
validation_custom_metadata = './background_images/val/metadata_train.json'

with open(validation_custom_metadata, 'r') as f:
    metadata = json.load(f)

# %%
import math
training_dataset_path = "./background_images/val"
training_bbox_data = './generated_dataset/labels/val/'
generated_train_dataset_path = "./generated_dataset/images/val/"
variations_per_image = 12

for image in metadata["images"]:
    image_filename = image["filename"]
    image_path = os.path.join(training_dataset_path, image_filename)
    # bg_img = image_preprocess(image_path, 1600)
    bg_img = cv2.imread(image_path)
    intermediate_img = bg_img

    # Save each variation with a unique filename
    filename, extension = os.path.splitext(image_filename)
    
    for var in range(variations_per_image):
        intermediate_img = bg_img

        # create a path string representing a fresh file for this image variation
        result_image_name = f"{filename}_variation{var}{extension}"
        result_metadata_name = f"{filename}_variation{var}.txt"
        training_bbox_data_file = f"{training_bbox_data}{result_metadata_name}"

        # flush previous contents if present
        with open(training_bbox_data_file,"w") as f:
            f.write("")
        
        with open(training_bbox_data_file, "a") as f:
            for box_num, box in enumerate(image["boxes"]):
                # 10% chance there is no highlight in this paragraph/box
                is_not_highlighted = random.randint(0, 9)
                if(is_not_highlighted<1):
                    continue
                
                # Get initial box parameters
                original_rect_start = box["rect_start"][:]
                width = box["width"]
                height = box["height"]
                thickness = box["thickness"]
                delta = box["line_spacing"]
                
                start_line = 0 # absolute line number from where highlight begins 
                max_lines = round(height // thickness, 0)
                lines_left_in_box = max_lines
                
                while lines_left_in_box>0:  
                    # 20% chance there is no highlight in the rest of the box
                    is_not_highlighted = random.randint(1, 10)
                    if(is_not_highlighted < 3):
                        lines_left_in_box = 0
                        continue
                        
                    # else, set random starting position within the remaining rectangle bounds
                    if(start_line == max_lines-1):
                        random_line_for_highlight_start = start_line
                    else:
                        random_line_for_highlight_start = random.randint(start_line, max_lines-1) # measured in number of lines, not pixels.
                    
                    lines_left_in_box = max_lines - random_line_for_highlight_start
                    variation_rect_start = original_rect_start[:]
                    variation_rect_start[1] += thickness*random_line_for_highlight_start
                    highlight_height =  random.randint(1, lines_left_in_box) # height of highlight-box in number of lines
                    
                    # new values for start_line and lines_left_in_box
                    start_line = random_line_for_highlight_start + highlight_height
                    lines_left_in_box = max_lines - start_line
    
                    # Ensure the rectangle is within the image bounds
                    #variation_rect_start[1] = min(variation_rect_start[1], resized_img_height - adjusted_height)
                    
                    l1, l2 = random.randint(0, 100), random.randint(0, 100)
                    max_offset = random.randint(0, 10)
                    color = random_rgb_color()
                    opacity = random.uniform(0.2, 0.6)
    
                    print(f"box = {box_num} \n rect_start = {variation_rect_start}\n width = {width} \n height = {highlight_height} \n opacity= {opacity}")
                    # Draw the adjusted rectangle
                    intermediate_img, bbox_metadata = draw_broken_box_with_subboxes(
                        intermediate_img, variation_rect_start, width, highlight_height, thickness, delta, l1, l2, max_offset, color, opacity
                    )

                    # create line to be appended to the image label file
                    line_to_be_appended = f"{bbox_metadata['class']} "
                    spaces=0
                    print(bbox_metadata)
                    for coord in bbox_metadata["poly"]:
                        line_to_be_appended = line_to_be_appended + f"{coord[0]} {coord[1]}"
                        if(spaces<8):
                            line_to_be_appended = line_to_be_appended + " "
                        spaces += 1
                    # append that line to the image path
                    f.write(f"{line_to_be_appended}\n")
                    
            result_image_filepath = os.path.join(generated_train_dataset_path, result_image_name)
            print(f"\n")

            (h, w) = intermediate_img.shape[:2]
            center = (w // 2, h // 2)
            degree_to_rotate = np.random.uniform(-2, 2)
            rotation_matrix = cv2.getRotationMatrix2D(center, degree_to_rotate, 1)
            rotated_image = cv2.warpAffine(intermediate_img, rotation_matrix, (w, h))
            
            cv2.imwrite(result_image_filepath, rotated_image)
            #json.dump(bbox_metadata, f)  # Append the JSON object (box) to the file
            f.write("\n")  # Write each box on a new line
# Out:
# box = 0
#  rect_start = [72, 196]
#  width = 417
#  height = 2
#  opacity= 0.43140097456018206
# num_subboxes = 2
# img_width = 584, img_height = 895
# {'class': 0, 'poly': [[0
# img_width = 584, img_height = 895
# {'class': 0, 'poly': [[0.22773972602739725, 0.2681564245810056], [0.22773972602739725, 0.2558659217877095], [0.8373287671232876, 0.2558659217877095], [0.8373287671232876, 0.2681564245810056], [0.8116438356164384, 0.2681564245810056], [0.8116438356164384, 0.28044692737430166], [0.1232876712328767, 0.28044692737430166], [0.1232876712328767, 0.2681564245810056]]}
# box = 2
#  rect_start = [54, 684]
#  width = 219
#  height = 10
#  opacity= 0.3588280843710902
# num_subboxes = 10
# img_width = 584, img_height = 895
# {'class': 0, 'poly': [[0.125, 0.7787709497206704], [0.125, 0.7642458100558659], [0.4674657534246575, 0.7642458100558659], [0.4674657534246575, 0.8949720670391061], [0.4332191780821918, 0.8949720670391061], [0.4332191780821918, 0.9094972067039107], [0.09246575342465753, 0.9094972067039107], [0.09246575342465753, 0.7787709497206704]]}
#
#
# box = 0
#  rect_start = [72, 229]
#  width = 417
#  height = 1
#  opacity= 0.3644298560090769
# num_subboxes = 1
# img_width = 584, img_height = 895
# {'class': 0, 'poly': [[0.2876712328767123, 0.2681564245810056], [0.2876712328767123, 0.2558659217877095], [0.8373287671232876, 0.2558659217877095], [0.8373287671232876, 0.2558659217877095], [0.690068493150685, 0.2558659217877095], [0.690068493150685, 0.2681564245810056], [0.1232876712328767, 0.2681564245810056], [0.1232876712328767, 0.2681564245810056]]}
# box = 0
#  rect_start = [72, 240]
#  width = 417
#  height = 1
#  opacity= 0.43700438650378837
# num_subboxes = 1
# img_width = 584, img_height = 895
# {'class': 0, 'poly': [[0.2842465753424658, 0.28044692737430166], [0.2842465753424658, 0.2681564245810056], [0.8373287671232876, 0.2681564245810056], [0.8373287671232876, 0.2681564245810056], [0.7551369863013698, 0.2681564245810056], [0.7551369863013698, 0.28044692737430166], [0.1232876712328767, 0.28044692737430166], [0.1232876712328767, 0.28044692737430166]]}
# box = 1
#  rect_start = [52, 544]
#  width = 221
#  height = 3
#  opacity= 0.24565596113712074
# num_subboxes = 3
# img_width = 584, img_height = 895
# {'class': 0, 'poly': [[0.1095890410958904, 0.6223463687150838], [0.1095890410958904, 0.6078212290502794], [0.4674657534246575, 0.6078212290502794], [0.4674657534246575, 0.6368715083798883], [0.2979452054794521, 0.6368715083798883], [0.2979452054794521, 0.6513966480446928], [0.08904109589041095, 0.6513966480446928], [0.08904109589041095, 0.6223463687150838]]}
# box = 3
#  rect_start = [290, 612]
#  width = 216
#  height = 4
#  opacity= 0.5000334207456303
# num_subboxes = 4
# img_width = 584, img_height = 895
# {'class': 0, 'poly': [[0.6472602739726028, 0.6983240223463687], [0.6472602739726028, 0.6837988826815642], [0.8664383561643836, 0.6837988826815642], [0.8664383561643836, 0.7273743016759776], [0.702054794520548, 0.7273743016759776], [0.702054794520548, 0.7418994413407821], [0.4965753424657534, 0.7418994413407821], [0.4965753424657534, 0.6983240223463687]]}
# box = 3
#  rect_start = [290, 664]
#  width = 216
#  height = 5
#  opacity= 0.4736791232174345
# num_subboxes = 5
# img_width = 584, img_height = 895
# {'class': 0, 'poly': [[0.6455479452054794, 0.7564245810055866], [0.6455479452054794, 0.7418994413407821], [0.8664383561643836, 0.7418994413407821], [0.8664383561643836, 0.8], [0.8424657534246576, 0.8], [0.8424657534246576, 0.8145251396648044], [0.4965753424657534, 0.8145251396648044], [0.4965753424657534, 0.7564245810055866]]}
# box = 3
#  rect_start = [290, 755]
#  width = 216
#  height = 5
#  opacity= 0.35084814948686
# num_subboxes = 5
# img_width = 584, img_height = 895
# {'class': 0, 'poly': [[0
# num_subboxes = 1
# img_width = 584, img_height = 895
# {'class': 0, 'poly': [[0.2773972602739726, 0.28044692737430166], [0.2773972602739726, 0.2681564245810056], [0.8373287671232876, 0.2681564245810056], [0.8373287671232876, 0.2681564245810056], [0.7071917808219178, 0.2681564245810056], [0.7071917808219178, 0.28044692737430166], [0.1232876712328767, 0.28044692737430166], [0.1232876712328767, 0.28044692737430166]]}
# box = 1
#  rect_start = [52, 492]
#  width = 221
#  height = 1
#  opacity= 0.22679388105380865
# num_subboxes = 1
# img_width = 584, img_height = 895
# {'class': 0, 'poly': [[0.19006849315068494, 0.5642458100558659], [0.19006849315068494, 0.5497206703910614], [0.4674657534246575, 0.5497206703910614], [0.4674657534246575, 0.5497206703910614], [0.4075342465753425, 0.5497206703910614], [0.4075342465753425, 0.5642458100558659], [0.08904109589041095, 0.5642458100558659], [0.08904109589041095, 0.5642458100558659]]}
# box = 1
#  rect_start = [52, 557]
#  width = 221
#  height = 1
#  opacity= 0.40575962069769067
# num_subboxes = 1
# img_width = 584, img_height = 895
# {'class': 0, 'poly': [[0.2089041095890411, 0.6368715083798883], [0.2089041095890411, 0.6223463687150838], [0.4674657534246575, 0.6223463687150838], [0.4674657534246575, 0.6223463687150838], [0.3133561643835616, 0.6223463687150838], [0.3133561643835616, 0.6368715083798883], [0.08904109589041095, 0.6368715083798883], [0.08904109589041095, 0.6368715083798883]]}
# box = 1
#  rect_start = [52, 570]
#  width = 221
#  height = 1
#  opacity= 0.33522877370797477
# num_subboxes = 1
# img_width = 584, img_height = 895
# {'class': 0, 'poly': [[0.18664383561643835, 0.6513966480446928], [0.18664383561643835, 0.6368715083798883], [0.4674657534246575, 0.6368715083798883], [0.4674657534246575, 0.6368715083798883], [0.4160958904109589, 0.6368715083798883], [0.4160958904109589, 0.6513966480446928], [0.08904109589041095, 0.6513966480446928], [0.08904109589041095, 0.6513966480446928]]}
# box = 3
#  rect_start = [290, 807]
#  width = 216
#  height = 1
#  opacity= 0.5806049872481405
# num_subboxes = 1
# img_width = 584, img_height = 895
# {'class': 0, 'poly': [[0.5376712328767124, 0.9162011173184358], [0.5376712328767124, 0.9016759776536313], [0.8664383561643836, 0.9016759776536313], [0.8664383561643836, 0.9016759776536313], [0.8476027397260274, 0.9016759776536313], [0.8476027397260274, 0.9162011173184358], [0.4965753424657534, 0.9162011173184358], [0.4965753424657534, 0.9162011173184358]]}
#
#
# box = 0
#  rect_start = [55, 116]
#  width = 607
#  height = 2
#  opacity= 0.5573006855640692
# num_subboxes = 2
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.08016304347826086, 0.1291139240506329], [0.08016304347826086, 0.09789029535864979], [0.8994565217391305, 0.09789029535864979], [0.8994565217391305, 0.1291139240506329], [0.8396739130434783, 0.1291139240506329], [0.8396739130434783, 0.16033755274261605], [0.07472826086956522, 0.16033755274261605], [0.07472826086956522, 0.1291139240506329]]}
# box = 0
#  rect_start = [55, 190]
#  width = 607
#  height = 2
#  opacity= 0.5055856103680382
# num_subboxes = 2
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.14130434782608695, 0.19156118143459916], [0.14130434782608695, 0.16033755274261605], [0.8994565217391305, 0.16033755274261605], [0.8994565217391305, 0.19156118143459916], [0.8029891304347826, 0.19156118143459916], [0.8029891304347826, 0.22278481012658227], [0.07472826086956522, 0.22278481012658227], [0.07472826086956522, 0.19156118143459916]]}
# box = 0
#  rect_start = [55, 264]
#  width = 607
#  height = 1
#  opacity= 0.5978179450877937
# num_subboxes = 1
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.20380434782608695, 0.2540084388185654], [0.20380434782608695, 0.22278481012658227], [0.8994565217391305, 0.22278481012658227], [0.8994565217391305, 0.22278481012658227], [0.7744565217391305, 0.22278481012658227], [0.7744565217391305, 0.2540084388185654], [0.07472826086956522, 0.2540084388185654], [0.07472826086956522, 0.2540084388185654]]}
# box = 1
#  rect_start = [57, 529]
#  width = 605
#  height = 1
#  opacity= 0.3548066855059079
# num_subboxes = 1
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.20244565217391305, 0.47763713080168774], [0.20244565217391305, 0.44641350210970465], [0.8994565217391305, 0.44641350210970465], [0.8994565217391305, 0.44641350210970465], [0.8627717391304348, 0.44641350210970465], [0.8627717391304348, 0.47763713080168774], [0.07744565217391304, 0.47763713080168774], [0.07744565217391304, 0.47763713080168774]]}
# box = 2
#  rect_start = [55, 823]
#  width = 605
#  height = 1
#  opacity= 0.35688188167415086
# num_subboxes = 1
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.09239130434782608, 0.7257383966244726], [0.09239130434782608, 0.6945147679324895], [0.8967391304347826, 0.6945147679324895], [0.8967391304347826, 0.6945147679324895], [0.8790760869565217, 0.6945147679324895], [0.8790760869565217, 0.7257383966244726], [0.07472826086956522, 0.7257383966244726], [0.07472826086956522, 0.7257383966244726]]}
# box = 3
#  rect_start = [55, 946]
#  width = 602
#  height = 2
#  opacity= 0.4319880038810268
# num_subboxes = 2
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.16168478260869565, 0.829535864978903], [0.16168478260869565, 0.7983122362869198], [0.8926630434782609, 0.7983122362869198], [0.8926630434782609, 0.829535864978903], [0.8342391304347826, 0.829535864978903], [0.8342391304347826, 0.8607594936708861], [0.07472826086956522, 0.8607594936708861], [0.07472826086956522, 0.829535864978903]]}
# box = 3
#  rect_start = [55, 1020]
#  width = 602
#  height = 1
#  opacity= 0.216352083554473
# num_subboxes = 1
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.15081521739130435, 0.8919831223628693], [0.15081521739130435, 0.8607594936708861], [0.8926630434782609, 0.8607594936708861], [0.8926630434782609, 0.8607594936708861], [0.813858695652174, 0.8607594936708861], [0.813858695652174, 0.8919831223628693], [0.07472826086956522, 0.8919831223628693], [0.07472826086956522, 0.8919831223628693]]}
#
#
# box = 0
#  rect_start = [55, 264]
#  width = 607
#  height = 1
#  opacity= 0.22206965072856094
# num_subboxes = 1
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.20380434782608695, 0.2540084388185654], [0.20380434782608695, 0.22278481012658227], [0.8994565217391305, 0.22278481012658227], [0.8994565217391305, 0.22278481012658227], [0.7676630434782609, 0.22278481012658227], [0.7676630434782609, 0.2540084388185654], [0.07472826086956522, 0.2540084388185654], [0.07472826086956522, 0.2540084388185654]]}
# box = 2
#  rect_start = [55, 786]
#  width = 605
#  height = 1
#  opacity= 0.5766562991628521
# num_subboxes = 1
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.12364130434782608, 0.6945147679324895], [0.12364130434782608, 0.6632911392405063], [0.8967391304347826, 0.6632911392405063], [0.8967391304347826, 0.6632911392405063], [0.8627717391304348, 0.6632911392405063], [0.8627717391304348, 0.6945147679324895], [0.07472826086956522, 0.6945147679324895], [0.07472826086956522, 0.6945147679324895]]}
#
#
# box = 0
#  rect_start = [55, 190]
#  width = 607
#  height = 3
#  opacity= 0.46174632647786956
# num_subboxes = 3
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.11413043478260869, 0.19156118143459916], [0.11413043478260869, 0.16033755274261605], [0.8994565217391305, 0.16033755274261605], [0.8994565217391305, 0.22278481012658227], [0.78125, 0.22278481012658227], [0.78125, 0.2540084388185654], [0.07472826086956522, 0.2540084388185654], [0.07472826086956522, 0.19156118143459916]]}
# box = 1
#  rect_start = [57, 344]
#  width = 605
#  height = 3
#  opacity= 0.3332085365078282
# num_subboxes = 3
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.11956521739130435, 0.32151898734177214], [0.11956521739130435, 0.290295358649789], [0.8994565217391305, 0.290295358649789], [0.8994565217391305, 0.3527426160337553], [0.8233695652173914, 0.3527426160337553], [0.8233695652173914, 0.38396624472573837], [0.07744565217391304, 0.38396624472573837], [0.07744565217391304, 0.32151898734177214]]}
# box = 1
#  rect_start = [57, 492]
#  width = 605
#  height = 1
#  opacity= 0.52444399437897
# num_subboxes = 1
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.1793478260869565, 0.44641350210970465], [0.1793478260869565, 0.4151898734177215], [0.8994565217391305, 0.4151898734177215], [0.8994565217391305, 0.4151898734177215], [0.7649456521739131, 0.4151898734177215], [0.7649456521739131, 0.44641350210970465], [0.07744565217391304, 0.44641350210970465], [0.07744565217391304, 0.44641350210970465]]}
# box = 1
#  rect_start = [57, 529]
#  width = 605
#  height = 1
#  opacity= 0.43097498235792464
# num_subboxes = 1
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.1480978260869565, 0.47763713080168774], [0.1480978260869565, 0.44641350210970465], [0.8994565217391305, 0.44641350210970465], [0.8994565217391305, 0.44641350210970465], [0.8695652173913043, 0.44641350210970465], [0.8695652173913043, 0.47763713080168774], [0.07744565217391304, 0.47763713080168774], [0.07744565217391304, 0.47763713080168774]]}
#
#
# box = 3
#  rect_start = [55, 1020]
#  width = 602
#  height = 1
#  opacity= 0.47244224595788387
# num_subboxes = 1
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.1331521739130435, 0.8919831223628693], [0.1331521739130435, 0.8607594936708861], [0.8926630434782609, 0.8607594936708861], [0.8926630434782609, 0.8607594936708861], [0.7744565217391305, 0.8607594936708861], [0.7744565217391305, 0.8919831223628693], [0.07472826086956522, 0.8919831223628693], [0.07472826086956522, 0.8919831223628693]]}
#
#
# box = 0
#  rect_start = [55, 190]
#  width = 607
#  height = 3
#  opacity= 0.5473774966241298
# num_subboxes = 3
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.16032608695652173, 0.19156118143459916], [0.16032608695652173, 0.16033755274261605], [0.8994565217391305, 0.16033755274261605], [0.8994565217391305, 0.22278481012658227], [0.7921195652173914, 0.22278481012658227], [0.7921195652173914, 0.2540084388185654], [0.07472826086956522, 0.2540084388185654], [0.07472826086956522, 0.19156118143459916]]}
# box = 1
#  rect_start = [57, 381]
#  width = 605
#  height = 2
#  opacity= 0.20418627985192736
# num_subboxes = 2
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.19701086956521738, 0.3527426160337553], [0.19701086956521738, 0.32151898734177214], [0.8994565217391305, 0.32151898734177214], [0.8994565217391305, 0.3527426160337553], [0.8029891304347826, 0.3527426160337553], [0.8029891304347826, 0.38396624472573837], [0.07744565217391304, 0.38396624472573837], [0.07744565217391304, 0.3527426160337553]]}
# box = 2
#  rect_start = [55, 601]
#  width = 605
#  height = 1
#  opacity= 0.44372176224355864
# num_subboxes = 1
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.13722826086956522, 0.5383966244725739], [0.13722826086956522, 0.5071729957805907], [0.8967391304347826, 0.5071729957805907], [0.8967391304347826, 0.5071729957805907], [0.8899456521739131, 0.5071729957805907], [0.8899456521739131, 0.5383966244725739], [0.07472826086956522, 0.5383966244725739], [0.07472826086956522, 0.5383966244725739]]}
# box = 3
#  rect_start = [55, 946]
#  width = 602
#  height = 3
#  opacity= 0.48201278790651136
# num_subboxes = 3
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.19972826086956522, 0.829535864978903], [0.19972826086956522, 0.7983122362869198], [0.8926630434782609, 0.7983122362869198], [0.8926630434782609, 0.8607594936708861], [0.7676630434782609, 0.8607594936708861], [0.7676630434782609, 0.8919831223628693], [0.07472826086956522, 0.8919831223628693], [0.07472826086956522, 0.829535864978903]]}
#
#
# box = 0
#  rect_start = [55, 190]
#  width = 607
#  height = 3
#  opacity= 0.5306903399176115
# num_subboxes = 3
# img_width = 736, img_height = 1185
# {'class': 0, 'poly': [[0.09375, 0.19156118143459916], [0.09375, 0.16033755274261605], [0.8994565217391305, 0.16033755274261605], [0.8994565217391305, 0.22278481012658227], [0.8464673913043478, 0.22278481012658227], [0.8464673913043478, 0.2540084388185654], [0.07472826086956522, 0.2540084388185654], [0.07472826086956522, 0.19156118143459916]]}
# box = 1
#  rect_start = [57, 492]
#  width = 605
#  height = 2
#  opacity= 0.3350233790397751
# num_subboxes = 2
# img_width = 736, img_height = 1185
# ...
#
#
# box = 0
#  rect_start = [2, 230]
#  width = 508
#  height = 8
#  opacity= 0.3304988565034342
# num_subboxes = 8
# img_width = 564, img_height = 846
# {'class': 0, 'poly': [[0.14184397163120568, 0.3215130023640662], [0.14184397163120568, 0.2718676122931442], [0.9042553191489362, 0.2718676122931442], [0.9042553191489362, 0.6193853427895981], [0.7464539007092199, 0.6193853427895981], [0.7464539007092199, 0.6690307328605201], [0.0035460992907801418, 0.6690307328605201], [0.0035460992907801418, 0.3215130023640662]]}
# box = 0
#  rect_start = [2, 692]
#  width = 508
#  height = 3
#  opacity= 0.2825365241114141
# num_subboxes = 3
# img_width = 564, img_height = 846
# {'class': 0, 'poly': [[0.1099290780141844, 0.8676122931442081], [0.1099290780141844, 0.817966903073286], [0.9042553191489362, 0.817966903073286], [0.9042553191489362, 0.91725768321513], [0.7393617021276596, 0.91725768321513], [0.7393617021276596, 0.966903073286052], [0.0035460992907801418, 0.966903073286052], [0.0035460992907801418, 0.8676122931442081]]}
#
#
# box = 0
#  rect_start = [2, 230]
#  width = 508
#  height = 9
#  opacity= 0.3434659153403973
# num_subboxes = 9
# img_width = 564, img_height = 846
# {'class': 0, 'poly': [[0.0035460992907801418, 0.3215130023640662], [0.0035460992907801418, 0.2718676122931442], [0.9042553191489362, 0.2718676122931442], [0.9042553191489362, 0.6690307328605201], [0.7712765957446809, 0.6690307328605201], [0.7712765957446809, 0.7186761229314421], [0.0035460992907801418, 0.7186761229314421], [0.0035460992907801418, 0.3215130023640662]]}
# box = 0
#  rect_start = [2, 692]
#  width = 508
#  height = 3
#  opacity= 0.49458089111283904
# num_subboxes = 3
# img_width = 564, img_height = 846
# {'class': 0, 'poly': [[0.16843971631205673, 0.8676122931442081], [0.16843971631205673, 0.817966903073286], [0.9042553191489362, 0.817966903073286], [0.9042553191489362, 0.91725768321513], [0.8226950354609929, 0.91725768321513], [0.8226950354609929, 0.966903073286052], [0.0035460992907801418, 0.966903073286052], [0.0035460992907801418, 0.8676122931442081]]}
#
#
# box = 0
#  rect_start = [2, 608]
#  width = 508
#  height = 1
#  opacity= 0.24651428394492758
# num_subboxes = 1
# img_width = 564, img_height = 846
# {'class': 0, 'poly': [[0.17375886524822695, 0.7683215130023641], [0.17375886524822695, 0.7186761229314421], [0.9042553191489362, 0.7186761229314421], [0.9042553191489362, 0.7186761229314421], [0.8812056737588653, 0.7186761229314421], [0.8812056737588653, 0.7683215130023641], [0.0035460992907801418, 0.7683215130023641], [0.0035460992907801418, 0.7683215130023641]]}
# box = 0
#  rect_start = [2, 776]
#  width = 508
#  height = 1
#  opacity= 0.45424792938759057
# num_subboxes = 1
# img_width = 564, img_height = 846
# {'class': 0, 'poly': [[0.15780141843971632, 0.966903073286052], [0.15780141843971632, 0.91725768321513], [0.9042553191489362, 0.91725768321513], [0.9042553191489362, 0.91725768321513], [0.7358156028368794, 0.91725768321513], [0.7358156028368794, 0.966903073286052], [0.0035460992907801418, 0.966903073286052], [0.0035460992907801418, 0.966903073286052]]}
#
#
# box = 0
#  rect_start = [2, 650]
#  width = 508
#  height = 2
#  opacity= 0.5649461352322869
# num_subboxes = 2
# img_width = 564, img_height = 846
# {'class': 0, 'poly': [[0.10815602836879433, 0.817966903073286], [0.10815602836879433, 0.7683215130023641], [0.9042553191489362, 0.7683215130023641], [0.9042553191489362, 0.817966903073286], [0.8812056737588653, 0.817966903073286], [0.8812056737588653, 0.8676122931442081], [0.0035460992907801418, 0.8676122931442081], [0.0035460992907801418, 0.817966903073286]]}
# box = 0
#  rect_start = [2, 776]
#  width = 508
#  height = 1
#  opacity= 0.20342116548135838
# num_subboxes = 1
# img_width = 564, img_height = 846
# {'class': 0, 'poly': [[0.13297872340425532, 0.966903073286052], [0.13297872340425532, 0.91725768321513], [0.9042553191489362, 0.91725768321513], [0.9042553191489362, 0.91725768321513], [0.799645390070922, 0.91725768321513], [0.799645390070922, 0.966903073286052], [0.0035460992907801418, 0.966903073286052], [0.0035460992907801418, 0.966903073286052]]}
#
#
# box = 0
#  rect_start = [2, 440]
#  width = 508
#  height = 8
#  opacity= 0.2441277320682973
# num_subboxes = 8
# img_width = 564, img_height = 846
# {'class': 0, 'poly': [[0.15780141843971632, 0.5697399527186762], [0.15780141843971632, 0.5200945626477541], [0.9042553191489362, 0.5200945626477541], [0.9042553191489362, 0.8676122931442081], [0.7588652482269503, 0.8676122931442081], [0.7588652482269503, 0.91725768321513], [0.0035460992907801418, 0.91725768321513], [0.0035460992907801418, 0.5697399527186762]]}
# box = 0
#  rect_start = [2, 776]
#  width = 508
#  height = 1
#  opacity= 0.2054616160282383
# num_subboxes = 1
# img_width = 564, img_height = 846
# {'class': 0, 'poly': [[0.03723404255319149, 0.966903073286052], [0.03723404255319149, 0.91725768321513], [0.9042553191489362, 0.91725768321513], [0.9042553191489362, 0.91725768321513], [0.8617021276595744, 0.91725768321513], [0.8617021276595744, 0.966903073286052], [0.0035460992907801418, 0.966903073286052], [0.0035460992907801418, 0.966903073286052]]}
#
#
#
#
# box = 0
#  rect_start = [2, 104]
#  width = 508
#  height = 5
#  opacity= 0.2951571533488094
# num_subboxes = 5
# img_width = 564, img_height = 846
# {'class': 0, 'poly': [[0.15780141843971632, 0.17257683215130024], [0.15780141843971632, 0.12293144208037825], [0.9042553191489362, 0.12293144208037825], [0.9042553191489362, 0.3215130023640662], [0.8156028368794326, 0.3215130023640662], [0.8156028368794326, 0.37115839243498816], [0.0035460992907801418, 0.37115839243498816], [0.0035460992907801418, 0.17257683215130024]]}
#
#
# box = 0
#  rect_start = [60, 653]
#  width = 617
#  height = 3
#  opacity= 0.3299710930277816
# num_subboxes = 3
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.19157608695652173, 0.5206422018348624], [0.19157608695652173, 0.49923547400611623], [0.9198369565217391, 0.49923547400611623], [0.9198369565217391, 0.5420489296636085], [0.8953804347826086, 0.5420489296636085], [0.8953804347826086, 0.5634556574923547], [0.08152173913043478, 0.5634556574923547], [0.08152173913043478, 0.5206422018348624]]}
# box = 0
#  rect_start = [60, 1073]
#  width = 617
#  height = 2
#  opacity= 0.4822771171713778
# num_subboxes = 2
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.18206521739130435, 0.841743119266055], [0.18206521739130435, 0.8203363914373089], [0.9198369565217391, 0.8203363914373089], [0.9198369565217391, 0.841743119266055], [0.8627717391304348, 0.841743119266055], [0.8627717391304348, 0.8631498470948012], [0.08152173913043478, 0.8631498470948012], [0.08152173913043478, 0.841743119266055]]}
# box = 0
#  rect_start = [60, 1129]
#  width = 617
#  height = 1
#  opacity= 0.2734966812936842
# num_subboxes = 1
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.20652173913043478, 0.8845565749235474], [0.20652173913043478, 0.8631498470948012], [0.9198369565217391, 0.8631498470948012], [0.9198369565217391, 0.8631498470948012], [0.8057065217391305, 0.8631498470948012], [0.8057065217391305, 0.8845565749235474], [0.08152173913043478, 0.8845565749235474], [0.08152173913043478, 0.8845565749235474]]}
#
#
# box = 0
#  rect_start = [60, 289]
#  width = 617
#  height = 14
#  opacity= 0.24312573126746254
# num_subboxes = 14
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.19293478260869565, 0.2423547400611621], [0.19293478260869565, 0.2209480122324159], [0.9198369565217391, 0.2209480122324159], [0.9198369565217391, 0.49923547400611623], [0.8396739130434783, 0.49923547400611623], [0.8396739130434783, 0.5206422018348624], [0.08152173913043478, 0.5206422018348624], [0.08152173913043478, 0.2423547400611621]]}
# box = 0
#  rect_start = [60, 905]
#  width = 617
#  height = 3
#  opacity= 0.47426917335408014
# num_subboxes = 3
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.17798913043478262, 0.713302752293578], [0.17798913043478262, 0.6918960244648318], [0.9198369565217391, 0.6918960244648318], [0.9198369565217391, 0.7347094801223242], [0.8016304347826086, 0.7347094801223242], [0.8016304347826086, 0.7561162079510704], [0.08152173913043478, 0.7561162079510704], [0.08152173913043478, 0.713302752293578]]}
# box = 0
#  rect_start = [60, 989]
#  width = 617
#  height = 3
#  opacity= 0.49280380142520236
# num_subboxes = 3
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.11956521739130435, 0.7775229357798165], [0.11956521739130435, 0.7561162079510704], [0.9198369565217391, 0.7561162079510704], [0.9198369565217391, 0.7989296636085627], [0.8817934782608695, 0.7989296636085627], [0.8817934782608695, 0.8203363914373089], [0.08152173913043478, 0.8203363914373089], [0.08152173913043478, 0.7775229357798165]]}
#
#
#
#
# box = 0
#  rect_start = [60, 737]
#  width = 617
#  height = 10
#  opacity= 0.44710944645293105
# num_subboxes = 10
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.16304347826086957, 0.5848623853211009], [0.16304347826086957, 0.5634556574923547], [0.9198369565217391, 0.5634556574923547], [0.9198369565217391, 0.7561162079510704], [0.8926630434782609, 0.7561162079510704], [0.8926630434782609, 0.7775229357798165], [0.08152173913043478, 0.7775229357798165], [0.08152173913043478, 0.5848623853211009]]}
# box = 0
#  rect_start = [60, 1073]
#  width = 617
#  height = 2
#  opacity= 0.2836398904998819
# num_subboxes = 2
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.08559782608695653, 0.841743119266055], [0.08559782608695653, 0.8203363914373089], [0.9198369565217391, 0.8203363914373089], [0.9198369565217391, 0.841743119266055], [0.8220108695652174, 0.841743119266055], [0.8220108695652174, 0.8631498470948012], [0.08152173913043478, 0.8631498470948012], [0.08152173913043478, 0.841743119266055]]}
# box = 0
#  rect_start = [60, 1129]
#  width = 617
#  height = 1
#  opacity= 0.530701117446646
# num_subboxes = 1
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.18478260869565216, 0.8845565749235474], [0.18478260869565216, 0.8631498470948012], [0.9198369565217391, 0.8631498470948012], [0.9198369565217391, 0.8631498470948012], [0.8817934782608695, 0.8631498470948012], [0.8817934782608695, 0.8845565749235474], [0.08152173913043478, 0.8845565749235474], [0.08152173913043478, 0.8845565749235474]]}
#
#
# box = 0
#  rect_start = [60, 233]
#  width = 617
#  height = 3
#  opacity= 0.338466154385208
# num_subboxes = 3
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.10733695652173914, 0.19954128440366972], [0.10733695652173914, 0.17813455657492355], [0.9198369565217391, 0.17813455657492355], [0.9198369565217391, 0.2209480122324159], [0.8953804347826086, 0.2209480122324159], [0.8953804347826086, 0.2423547400611621], [0.08152173913043478, 0.2423547400611621], [0.08152173913043478, 0.19954128440366972]]}
# box = 0
#  rect_start = [60, 401]
#  width = 617
#  height = 16
#  opacity= 0.2322416253753021
# num_subboxes = 16
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.20652173913043478, 0.32798165137614677], [0.20652173913043478, 0.3065749235474006], [0.9198369565217391, 0.3065749235474006], [0.9198369565217391, 0.6276758409785933], [0.8247282608695652, 0.6276758409785933], [0.8247282608695652, 0.6490825688073395], [0.08152173913043478, 0.6490825688073395], [0.08152173913043478, 0.32798165137614677]]}
# box = 0
#  rect_start = [60, 1101]
#  width = 617
#  height = 2
#  opacity= 0.3796030100686202
# num_subboxes = 2
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.11141304347826086, 0.8631498470948012], [0.11141304347826086, 0.841743119266055], [0.9198369565217391, 0.841743119266055], [0.9198369565217391, 0.8631498470948012], [0.8274456521739131, 0.8631498470948012], [0.8274456521739131, 0.8845565749235474], [0.08152173913043478, 0.8845565749235474], [0.08152173913043478, 0.8631498470948012]]}
#
#
# box = 0
#  rect_start = [60, 1073]
#  width = 617
#  height = 3
#  opacity= 0.27446104130505994
# num_subboxes = 3
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.1480978260869565, 0.841743119266055], [0.1480978260869565, 0.8203363914373089], [0.9198369565217391, 0.8203363914373089], [0.9198369565217391, 0.8631498470948012], [0.8967391304347826, 0.8631498470948012], [0.8967391304347826, 0.8845565749235474], [0.08152173913043478, 0.8845565749235474], [0.08152173913043478, 0.841743119266055]]}
#
#
# box = 0
#  rect_start = [60, 1073]
#  width = 617
#  height = 1
#  opacity= 0.5435113573200105
# num_subboxes = 1
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.13994565217391305, 0.841743119266055], [0.13994565217391305, 0.8203363914373089], [0.9198369565217391, 0.8203363914373089], [0.9198369565217391, 0.8203363914373089], [0.8464673913043478, 0.8203363914373089], [0.8464673913043478, 0.841743119266055], [0.08152173913043478, 0.841743119266055], [0.08152173913043478, 0.841743119266055]]}
# box = 0
#  rect_start = [60, 1129]
#  width = 617
#  height = 1
#  opacity= 0.5299656692938917
# num_subboxes = 1
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.09103260869565218, 0.8845565749235474], [0.09103260869565218, 0.8631498470948012], [0.9198369565217391, 0.8631498470948012], [0.9198369565217391, 0.8631498470948012], [0.8980978260869565, 0.8631498470948012], [0.8980978260869565, 0.8845565749235474], [0.08152173913043478, 0.8845565749235474], [0.08152173913043478, 0.8845565749235474]]}
#
#
# box = 0
#  rect_start = [60, 289]
#  width = 617
#  height = 25
#  opacity= 0.5632967216090696
# num_subboxes = 25
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.2078804347826087, 0.2423547400611621], [0.2078804347826087, 0.2209480122324159], [0.9198369565217391, 0.2209480122324159], [0.9198369565217391, 0.7347094801223242], [0.8940217391304348, 0.7347094801223242], [0.8940217391304348, 0.7561162079510704], [0.08152173913043478, 0.7561162079510704], [0.08152173913043478, 0.2423547400611621]]}
# box = 0
#  rect_start = [60, 1045]
#  width = 617
#  height = 1
#  opacity= 0.3626545191054376
# num_subboxes = 1
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.10461956521739131, 0.8203363914373089], [0.10461956521739131, 0.7989296636085627], [0.9198369565217391, 0.7989296636085627], [0.9198369565217391, 0.7989296636085627], [0.8070652173913043, 0.7989296636085627], [0.8070652173913043, 0.8203363914373089], [0.08152173913043478, 0.8203363914373089], [0.08152173913043478, 0.8203363914373089]]}
# box = 0
#  rect_start = [60, 1101]
#  width = 617
#  height = 2
#  opacity= 0.44936509857298534
# num_subboxes = 2
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.16304347826086957, 0.8631498470948012], [0.16304347826086957, 0.841743119266055], [0.9198369565217391, 0.841743119266055], [0.9198369565217391, 0.8631498470948012], [0.9089673913043478, 0.8631498470948012], [0.9089673913043478, 0.8845565749235474], [0.08152173913043478, 0.8845565749235474], [0.08152173913043478, 0.8631498470948012]]}
#
#
#
#
# box = 0
#  rect_start = [60, 373]
#  width = 617
#  height = 8
#  opacity= 0.21374792505133497
# num_subboxes = 8
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.08831521739130435, 0.3065749235474006], [0.08831521739130435, 0.2851681957186544], [0.9198369565217391, 0.2851681957186544], [0.9198369565217391, 0.4350152905198777], [0.904891304347826, 0.4350152905198777], [0.904891304347826, 0.45642201834862384], [0.08152173913043478, 0.45642201834862384], [0.08152173913043478, 0.3065749235474006]]}
#
#
#
#
# box = 0
#  rect_start = [60, 1129]
#  width = 617
#  height = 1
#  opacity= 0.590621497770802
# num_subboxes = 1
# img_width = 736, img_height = 1308
# {'class': 0, 'poly': [[0.09646739130434782, 0.8845565749235474], [0.09646739130434782, 0.8631498470948012], [0.9198369565217391, 0.8631498470948012], [0.9198369565217391, 0.8631498470948012], [0.8070652173913043, 0.8631498470948012], [0.8070652173913043, 0.8845565749235474], [0.08152173913043478, 0.8845565749235474], [0.08152173913043478, 0.8845565749235474]]}
